# %% [markdown]
# # Link Prediction with GCN

# %%
import networkx as nx
import pandas as pd
import numpy as np
from scipy import stats
import os
import time
import stellargraph as sg
from stellargraph import StellarGraph
import scipy.sparse as sp
from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GCN
from tensorflow import keras
from tensorflow.keras import layers, optimizers, losses, metrics, Model, regularizers
from sklearn import preprocessing, feature_extraction, model_selection
from copy import deepcopy
import matplotlib.pyplot as plt
from stellargraph import datasets
from IPython.display import display, HTML
import dill
from sklearn.preprocessing import LabelEncoder
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
import math
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
from copy import deepcopy
import torch
from scipy.sparse import identity
import numpy as np
import logging

import plotly.graph_objects as go
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.metrics import precision_recall_curve
from collections import Counter
# from tqdm import tqdm_notebook as tqdm
# tqdm().pandas()
import json
import pickle
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.model_selection import StratifiedKFold
from keras.models import load_model
from sklearn.metrics import log_loss
from keras import regularizers
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import Flatten
import tensorflow as tf
import random
from matplotlib import pyplot as plt
import seaborn as sns
import os
import umap
from sklearn.cluster import KMeans
from keras import backend as K
from sklearn.manifold import TSNE
from IPython.core.display import display, HTML
from sklearn.preprocessing import StandardScaler, MinMaxScaler
display(HTML("<style>.container { width:80% !important; }</style>"))
from plotly.offline import init_notebook_mode, iplot
from sklearn.decomposition import PCA
from stellargraph.data import EdgeSplitter
from stellargraph.mapper import FullBatchLinkGenerator
from stellargraph.layer import GCN, LinkEmbedding


from tensorflow import keras
from sklearn import preprocessing, feature_extraction, model_selection

from stellargraph import globalvar
from stellargraph import datasets
from IPython.display import display, HTML
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## Loading the CORA network

# %%
data_path = "keyword_and_abstract_SentenceTransform/"

# %%
def prepare_data_for_stellargraph(out_path):
    def _load_raw_inputs(sis_sparse=True):
        with open(out_path+'new_edges.pkl', 'rb') as f:     
            edges = dill.load(f)

        with open(out_path+'new_features.pkl', 'rb') as f:     
            features = dill.load(f)
            
        with open(out_path+'new_labels.pkl', 'rb') as f:     
            labels = dill.load(f)
            
        return edges, features, labels
    
    print("Reading raw inputs...")
    edges, features, labels = _load_raw_inputs()
    
    
    print("creating nodes...")
    tmp_df = pd.concat( [pd.DataFrame(edges), pd.DataFrame([1]*len(edges))],1)
    tmp_df.columns = ["source", "target", "weight"]
    
    print("creating edges...")
    feature_df = pd.DataFrame(features)
    feature_df.columns = [f"w{i}" for i in range(feature_df.shape[1])]
    
    print("creating labels...")
    label_series = pd.DataFrame({ "label": labels})["label"]


    my_graph = StellarGraph(
        {"paper": feature_df}, {"cites": tmp_df}
    )
    print("Done!")
    
    print(my_graph.info())
    return my_graph, label_series
G, subjects = prepare_data_for_stellargraph(data_path)
# Out:
# Reading raw inputs...
# creating nodes...
# creating edges...
# creating labels...
# Done!
# StellarGraph: Undirected multigraph
#  Nodes: 1178, Edges: 5699
#
#  Node types:
#   paper: [1178]
#     Features: float32 vector, length 868
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [5699]
#         Weights: all 1 (default)
#         Features: none

# %%
subjects.tail()
# Out:
# 1173    2
# 1174    2
# 1175    2
# 1176    2
# 1177    2
# Name: label, dtype: int64

# %% [markdown]
# ### Splitting the data

# %%
# Define an edge splitter on the original graph G:
edge_splitter_test = EdgeSplitter(G)

# Randomly sample a fraction p=0.1 of all positive links, and same number of negative links, from G, and obtain the
# reduced graph G_test with the sampled links removed:
G_test, edge_ids_test, edge_labels_test = edge_splitter_test.train_test_split(
    p=0.1, method="global", keep_connected=True
)
# Out:
# ** Sampled 569 positive and 569 negative edges. **

# %%
# Define an edge splitter on the reduced graph G_test:
edge_splitter_train = EdgeSplitter(G_test)

# Randomly sample a fraction p=0.1 of all positive links, and same number of negative links, from G_test, and obtain the
# reduced graph G_train with the sampled links removed:
G_train, edge_ids_train, edge_labels_train = edge_splitter_train.train_test_split(
    p=0.1, method="global", keep_connected=True
)
# Out:
# ** Sampled 513 positive and 513 negative edges. **

# %%
print(G.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 1178, Edges: 5699
#
#  Node types:
#   paper: [1178]
#     Features: float32 vector, length 868
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [5699]
#         Weights: all 1 (default)
#         Features: none

# %%
print(G_test.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 1178, Edges: 5130
#
#  Node types:
#   paper: [1178]
#     Features: float32 vector, length 868
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [5130]
#         Weights: all 1 (default)
#         Features: none

# %%
print(G_train.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 1178, Edges: 4617
#
#  Node types:
#   paper: [1178]
#     Features: float32 vector, length 868
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [4617]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# ### Creating the GCN model in Keras

# %%
epochs = 700
train_gen = FullBatchLinkGenerator(G_train, method="gcn")
train_flow = train_gen.flow(edge_ids_train, edge_labels_train)
test_gen = FullBatchLinkGenerator(G_test, method="gcn")
test_flow = test_gen.flow(edge_ids_test, edge_labels_test)

gcn = GCN(
    layer_sizes=[80, 32], activations=["elu", "elu"], generator=train_gen, dropout=0.25)
x_inp, x_out = gcn.in_out_tensors()

prediction = LinkEmbedding(activation="relu", method="ip")(x_out)
prediction = keras.layers.Reshape((-1,))(prediction)

model = keras.Model(inputs=x_inp, outputs=prediction)

model.compile(
    optimizer=keras.optimizers.Adam(lr=0.0001),
    loss=keras.losses.binary_crossentropy,
    metrics=["binary_accuracy"],
)

init_train_metrics = model.evaluate(train_flow)
init_test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
    
history = model.fit(
    train_flow, epochs=epochs, validation_data=test_flow, verbose=2, shuffle=False
)
# Out:
# Using GCN (local pooling) filters...
# Using GCN (local pooling) filters...
# 1/1 [==============================] - 0s 965us/step - loss: 7.6246 - binary_accuracy: 0.5000
# 1/1 [==============================] - 0s 869us/step - loss: 7.6246 - binary_accuracy: 0.5000
#
# Train Set Metrics of the initial (untrained) model:
# 	loss: 7.6246
# 	binary_accuracy: 0.5000
#
# Test Set Metrics of the initial (untrained) model:
# 	loss: 7.6246
# 	binary_accuracy: 0.5000
# Epoch 1/700
# 1/1 - 0s - loss: 7.5897 - binary_accuracy: 0.5000 - val_loss: 7.6246 - val_binary_accuracy: 0.5000
# Epoch 2/700
# 1/1 - 0s - loss: 7.6246 - binary_accuracy: 0.5000 - val_loss: 7.6246 - val_binary_accuracy: 0.5000
# Epoch 3/700
# 1/1 - 0s - loss: 7.6246 - binary_accuracy: 0.5000 - val_loss: 7.6246 - val_binary_accuracy: 0.5000
# Epoch 4/700
# 1/1 - 0s - loss: 7.5996 - binary_accuracy: 0.5000 - val_loss: 7.6246 - val_binary_accuracy: 0.5000
# Epoch 5/700
# 1/1 - 0s - loss: 7.5625 - binary_accuracy: 0.5000 - val_loss: 7.6149 - val_binary_accuracy: 0.5000
# Epoch 6/700
# 1/1 - 0s - loss: 7.5870 - binary_accuracy: 0.5000 - val_loss: 7.6134 - val_binary_accuracy: 0.5000
# Epoch 7/700
# 1/1 - 0s - loss: 7.5570 - binary_accuracy: 0.5019 - val_loss: 7.6039 - val_binary_accuracy: 0.5000
# Epoch 8/700
# 1/1 - 0s - loss: 7.4644 - binary_accuracy: 0.5049 - val_loss: 7.5795 - val_binary_accuracy: 0.5000
# Epoch 9/700
# 1/1 - 0s - loss: 7.5144 - binary_accuracy: 0.5029 - val_loss: 7.5550 - val_binary_accuracy: 0.5000
# Epoch 10/700
# 1/1 - 0s - loss: 7.5023 - binary_accuracy: 0.5000 - val_loss: 7.5424 - val_binary_accuracy: 0.5000
# Epoch 11/700
# 1/1 - 0s - loss: 7.3832 - binary_accuracy: 0.5058 - val_loss: 7.4760 - val_binary_accuracy: 0.5009
# Epoch 12/700
# 1/1 - 0s - loss: 7.2166 - binary_accuracy: 0.5010 - val_loss: 7.4155 - val_binary_accuracy: 0.5026
# Epoch 13/700
# 1/1 - 0s - loss: 7.1056 - binary_accuracy: 0.5049 - val_loss: 7.2193 - val_binary_accuracy: 0.5035
# Epoch 14/700
# 1/1 - 0s - loss: 6.8132 - binary_accuracy: 0.5117 - val_loss: 6.8087 - val_binary_accuracy: 0.5035
# Epoch 15/700
# 1/1 - 0s - loss: 6.2785 - binary_accuracy: 0.5117 - val_loss: 6.1635 - val_binary_accuracy: 0.5079
# Epoch 16/700
# 1/1 - 0s - loss: 5.7651 - binary_accuracy: 0.5302 - val_loss: 5.2543 - val_binary_accuracy: 0.5149
# Epoch 17/700
# 1/1 - 0s - loss: 4.8367 - binary_accuracy: 0.5536 - val_loss: 4.0092 - val_binary_accuracy: 0.5439
# Epoch 18/700
# 1/1 - 0s - loss: 3.9254 - binary_accuracy: 0.5721 - val_loss: 2.5652 - val_binary_accuracy: 0.5861
# Epoch 19/700
# 1/1 - 0s - loss: 2.5474 - binary_accuracy: 0.6072 - val_loss: 1.8755 - val_binary_accuracy: 0.6239
# Epoch 20/700
# 1/1 - 0s - loss: 1.9552 - binary_accuracy: 0.6257 - val_loss: 1.3433 - val_binary_accuracy: 0.6634
# Epoch 21/700
# 1/1 - 0s - loss: 1.3646 - binary_accuracy: 0.6540 - val_loss: 0.9799 - val_binary_accuracy: 0.6977
# Epoch 22/700
# 1/1 - 0s - loss: 1.0488 - binary_accuracy: 0.7183 - val_loss: 0.7954 - val_binary_accuracy: 0.7241
# Epoch 23/700
# 1/1 - 0s - loss: 0.9509 - binary_accuracy: 0.7008 - val_loss: 0.7577 - val_binary_accuracy: 0.7364
# Epoch 24/700
# 1/1 - 0s - loss: 0.8463 - binary_accuracy: 0.7251 - val_loss: 0.6891 - val_binary_accuracy: 0.7460
# Epoch 25/700
# 1/1 - 0s - loss: 0.7720 - binary_accuracy: 0.7310 - val_loss: 0.6643 - val_binary_accuracy: 0.7540
# Epoch 26/700
# 1/1 - 0s - loss: 0.8714 - binary_accuracy: 0.7222 - val_loss: 0.6563 - val_binary_accuracy: 0.7540
# Epoch 27/700
# 1/1 - 0s - loss: 0.7272 - binary_accuracy: 0.7135 - val_loss: 0.6560 - val_binary_accuracy: 0.7522
# Epoch 28/700
# 1/1 - 0s - loss: 0.7275 - binary_accuracy: 0.7203 - val_loss: 0.6457 - val_binary_accuracy: 0.7487
# Epoch 29/700
# 1/1 - 0s - loss: 0.7869 - binary_accuracy: 0.7232 - val_loss: 0.6340 - val_binary_accuracy: 0.7513
# Epoch 30/700
# 1/1 - 0s - loss: 0.7328 - binary_accuracy: 0.7183 - val_loss: 0.6323 - val_binary_accuracy: 0.7513
# Epoch 31/700
# 1/1 - 0s - loss: 0.7084 - binary_accuracy: 0.7251 - val_loss: 0.6381 - val_binary_accuracy: 0.7531
# Epoch 32/700
# 1/1 - 0s - loss: 0.7001 - binary_accuracy: 0.7495 - val_loss: 0.6352 - val_binary_accuracy: 0.7575
# Epoch 33/700
# 1/1 - 0s - loss: 0.7377 - binary_accuracy: 0.7320 - val_loss: 0.6226 - val_binary_accuracy: 0.7566
# Epoch 34/700
# 1/1 - 0s - loss: 0.7122 - binary_accuracy: 0.7495 - val_loss: 0.6091 - val_binary_accuracy: 0.7566
# Epoch 35/700
# 1/1 - 0s - loss: 0.7058 - binary_accuracy: 0.7359 - val_loss: 0.6027 - val_binary_accuracy: 0.7540
# Epoch 36/700
# 1/1 - 0s - loss: 0.7740 - binary_accuracy: 0.7164 - val_loss: 0.5987 - val_binary_accuracy: 0.7531
# Epoch 37/700
# 1/1 - 0s - loss: 0.7472 - binary_accuracy: 0.7290 - val_loss: 0.6050 - val_binary_accuracy: 0.7583
# Epoch 38/700
# 1/1 - 0s - loss: 0.6361 - binary_accuracy: 0.7271 - val_loss: 0.6017 - val_binary_accuracy: 0.7566
# Epoch 39/700
# 1/1 - 0s - loss: 0.6899 - binary_accuracy: 0.7261 - val_loss: 0.5884 - val_binary_accuracy: 0.7583
# Epoch 40/700
# 1/1 - 0s - loss: 0.8042 - binary_accuracy: 0.7212 - val_loss: 0.5850 - val_binary_accuracy: 0.7557
# Epoch 41/700
# 1/1 - 0s - loss: 0.7505 - binary_accuracy: 0.7310 - val_loss: 0.5826 - val_binary_accuracy: 0.7610
# Epoch 42/700
# 1/1 - 0s - loss: 0.6956 - binary_accuracy: 0.7427 - val_loss: 0.5808 - val_binary_accuracy: 0.7610
# Epoch 43/700
# 1/1 - 0s - loss: 0.7619 - binary_accuracy: 0.7310 - val_loss: 0.5794 - val_binary_accuracy: 0.7601
# Epoch 44/700
# 1/1 - 0s - loss: 0.7069 - binary_accuracy: 0.7349 - val_loss: 0.5781 - val_binary_accuracy: 0.7592
# Epoch 45/700
# 1/1 - 0s - loss: 0.6004 - binary_accuracy: 0.7524 - val_loss: 0.5767 - val_binary_accuracy: 0.7592
# Epoch 46/700
# 1/1 - 0s - loss: 0.6655 - binary_accuracy: 0.7339 - val_loss: 0.5584 - val_binary_accuracy: 0.7619
# Epoch 47/700
# 1/1 - 0s - loss: 0.6592 - binary_accuracy: 0.7320 - val_loss: 0.5555 - val_binary_accuracy: 0.7698
# Epoch 48/700
# 1/1 - 0s - loss: 0.7139 - binary_accuracy: 0.7456 - val_loss: 0.5553 - val_binary_accuracy: 0.7724
# Epoch 49/700
# 1/1 - 0s - loss: 0.6982 - binary_accuracy: 0.7641 - val_loss: 0.5571 - val_binary_accuracy: 0.7742
# Epoch 50/700
# 1/1 - 0s - loss: 0.5779 - binary_accuracy: 0.7563 - val_loss: 0.5515 - val_binary_accuracy: 0.7724
# Epoch 51/700
# 1/1 - 0s - loss: 0.6876 - binary_accuracy: 0.7164 - val_loss: 0.5350 - val_binary_accuracy: 0.7707
# Epoch 52/700
# 1/1 - 0s - loss: 0.7562 - binary_accuracy: 0.7290 - val_loss: 0.5381 - val_binary_accuracy: 0.7575
# Epoch 53/700
# 1/1 - 0s - loss: 0.6076 - binary_accuracy: 0.7378 - val_loss: 0.5550 - val_binary_accuracy: 0.7417
# Epoch 54/700
# 1/1 - 0s - loss: 0.6072 - binary_accuracy: 0.7378 - val_loss: 0.5610 - val_binary_accuracy: 0.7381
# Epoch 55/700
# 1/1 - 0s - loss: 0.6382 - binary_accuracy: 0.7378 - val_loss: 0.5652 - val_binary_accuracy: 0.7329
# Epoch 56/700
# 1/1 - 0s - loss: 0.6316 - binary_accuracy: 0.7407 - val_loss: 0.5768 - val_binary_accuracy: 0.7293
# Epoch 57/700
# 1/1 - 0s - loss: 0.6929 - binary_accuracy: 0.7105 - val_loss: 0.5757 - val_binary_accuracy: 0.7320
# Epoch 58/700
# 1/1 - 0s - loss: 0.6169 - binary_accuracy: 0.7446 - val_loss: 0.5724 - val_binary_accuracy: 0.7337
# Epoch 59/700
# 1/1 - 0s - loss: 0.6917 - binary_accuracy: 0.7359 - val_loss: 0.5669 - val_binary_accuracy: 0.7381
# Epoch 60/700
# 1/1 - 0s - loss: 0.6396 - binary_accuracy: 0.7339 - val_loss: 0.5610 - val_binary_accuracy: 0.7496
# Epoch 61/700
# 1/1 - 0s - loss: 0.5808 - binary_accuracy: 0.7495 - val_loss: 0.5557 - val_binary_accuracy: 0.7522
# Epoch 62/700
# 1/1 - 0s - loss: 0.6079 - binary_accuracy: 0.7593 - val_loss: 0.5599 - val_binary_accuracy: 0.7619
# Epoch 63/700
# 1/1 - 0s - loss: 0.5979 - binary_accuracy: 0.7329 - val_loss: 0.5563 - val_binary_accuracy: 0.7636
# Epoch 64/700
# 1/1 - 0s - loss: 0.6000 - binary_accuracy: 0.7573 - val_loss: 0.5557 - val_binary_accuracy: 0.7707
# Epoch 65/700
# 1/1 - 0s - loss: 0.6237 - binary_accuracy: 0.7661 - val_loss: 0.5663 - val_binary_accuracy: 0.7750
# Epoch 66/700
# 1/1 - 0s - loss: 0.6227 - binary_accuracy: 0.7632 - val_loss: 0.5654 - val_binary_accuracy: 0.7777
# Epoch 67/700
# 1/1 - 0s - loss: 0.6982 - binary_accuracy: 0.7544 - val_loss: 0.5786 - val_binary_accuracy: 0.7777
# Epoch 68/700
# 1/1 - 0s - loss: 0.6294 - binary_accuracy: 0.7680 - val_loss: 0.5985 - val_binary_accuracy: 0.7759
# Epoch 69/700
# 1/1 - 0s - loss: 0.6131 - binary_accuracy: 0.7690 - val_loss: 0.6076 - val_binary_accuracy: 0.7733
# Epoch 70/700
# 1/1 - 0s - loss: 0.6598 - binary_accuracy: 0.7534 - val_loss: 0.6082 - val_binary_accuracy: 0.7733
# Epoch 71/700
# 1/1 - 0s - loss: 0.7203 - binary_accuracy: 0.7729 - val_loss: 0.6063 - val_binary_accuracy: 0.7777
# Epoch 72/700
# 1/1 - 0s - loss: 0.6457 - binary_accuracy: 0.7602 - val_loss: 0.5766 - val_binary_accuracy: 0.7803
# Epoch 73/700
# 1/1 - 0s - loss: 0.5857 - binary_accuracy: 0.7700 - val_loss: 0.5663 - val_binary_accuracy: 0.7830
# Epoch 74/700
# 1/1 - 0s - loss: 0.6083 - binary_accuracy: 0.7710 - val_loss: 0.5554 - val_binary_accuracy: 0.7689
# Epoch 75/700
# 1/1 - 0s - loss: 0.5036 - binary_accuracy: 0.7778 - val_loss: 0.5569 - val_binary_accuracy: 0.7742
# Epoch 76/700
# 1/1 - 0s - loss: 0.6001 - binary_accuracy: 0.7505 - val_loss: 0.5581 - val_binary_accuracy: 0.7724
# Epoch 77/700
# 1/1 - 0s - loss: 0.5882 - binary_accuracy: 0.7788 - val_loss: 0.5594 - val_binary_accuracy: 0.7715
# Epoch 78/700
# 1/1 - 0s - loss: 0.6488 - binary_accuracy: 0.7485 - val_loss: 0.5692 - val_binary_accuracy: 0.7698
# Epoch 79/700
# 1/1 - 0s - loss: 0.6320 - binary_accuracy: 0.7485 - val_loss: 0.5708 - val_binary_accuracy: 0.7715
# Epoch 80/700
# 1/1 - 0s - loss: 0.5851 - binary_accuracy: 0.7544 - val_loss: 0.5694 - val_binary_accuracy: 0.7707
# Epoch 81/700
# 1/1 - 0s - loss: 0.5926 - binary_accuracy: 0.7602 - val_loss: 0.5676 - val_binary_accuracy: 0.7698
# Epoch 82/700
# 1/1 - 0s - loss: 0.5813 - binary_accuracy: 0.7788 - val_loss: 0.5663 - val_binary_accuracy: 0.7707
# Epoch 83/700
# 1/1 - 0s - loss: 0.5285 - binary_accuracy: 0.7729 - val_loss: 0.5647 - val_binary_accuracy: 0.7733
# Epoch 84/700
# 1/1 - 0s - loss: 0.5889 - binary_accuracy: 0.7495 - val_loss: 0.5542 - val_binary_accuracy: 0.7715
# Epoch 85/700
# 1/1 - 0s - loss: 0.5675 - binary_accuracy: 0.7671 - val_loss: 0.5523 - val_binary_accuracy: 0.7733
# Epoch 86/700
# 1/1 - 0s - loss: 0.6048 - binary_accuracy: 0.7710 - val_loss: 0.5516 - val_binary_accuracy: 0.7707
# Epoch 87/700
# 1/1 - 0s - loss: 0.6457 - binary_accuracy: 0.7671 - val_loss: 0.5514 - val_binary_accuracy: 0.7733
# Epoch 88/700
# 1/1 - 0s - loss: 0.6200 - binary_accuracy: 0.7388 - val_loss: 0.5514 - val_binary_accuracy: 0.7724
# Epoch 89/700
# 1/1 - 0s - loss: 0.5787 - binary_accuracy: 0.7437 - val_loss: 0.5488 - val_binary_accuracy: 0.7698
# Epoch 90/700
# 1/1 - 0s - loss: 0.5757 - binary_accuracy: 0.7671 - val_loss: 0.5612 - val_binary_accuracy: 0.7566
# Epoch 91/700
# 1/1 - 0s - loss: 0.6059 - binary_accuracy: 0.7602 - val_loss: 0.5858 - val_binary_accuracy: 0.7452
# Epoch 92/700
# 1/1 - 0s - loss: 0.6433 - binary_accuracy: 0.7505 - val_loss: 0.5839 - val_binary_accuracy: 0.7399
# Epoch 93/700
# 1/1 - 0s - loss: 0.6693 - binary_accuracy: 0.7290 - val_loss: 0.6010 - val_binary_accuracy: 0.7364
# Epoch 94/700
# 1/1 - 0s - loss: 0.6938 - binary_accuracy: 0.7154 - val_loss: 0.6296 - val_binary_accuracy: 0.7311
# Epoch 95/700
# 1/1 - 0s - loss: 0.7744 - binary_accuracy: 0.7339 - val_loss: 0.6457 - val_binary_accuracy: 0.7337
# Epoch 96/700
# 1/1 - 0s - loss: 0.8786 - binary_accuracy: 0.7144 - val_loss: 0.6574 - val_binary_accuracy: 0.7276
# Epoch 97/700
# 1/1 - 0s - loss: 0.8096 - binary_accuracy: 0.7203 - val_loss: 0.6492 - val_binary_accuracy: 0.7258
# Epoch 98/700
# 1/1 - 0s - loss: 0.6963 - binary_accuracy: 0.7524 - val_loss: 0.6375 - val_binary_accuracy: 0.7241
# Epoch 99/700
# 1/1 - 0s - loss: 0.8320 - binary_accuracy: 0.7203 - val_loss: 0.6016 - val_binary_accuracy: 0.7258
# Epoch 100/700
# 1/1 - 0s - loss: 0.8139 - binary_accuracy: 0.7164 - val_loss: 0.5988 - val_binary_accuracy: 0.7267
# Epoch 101/700
# 1/1 - 0s - loss: 0.7198 - binary_accuracy: 0.7135 - val_loss: 0.5875 - val_binary_accuracy: 0.7250
# Epoch 102/700
# 1/1 - 0s - loss: 0.6741 - binary_accuracy: 0.7193 - val_loss: 0.5753 - val_binary_accuracy: 0.7320
# Epoch 103/700
# 1/1 - 0s - loss: 0.6528 - binary_accuracy: 0.7437 - val_loss: 0.5821 - val_binary_accuracy: 0.7399
# Epoch 104/700
# 1/1 - 0s - loss: 0.6191 - binary_accuracy: 0.7339 - val_loss: 0.5796 - val_binary_accuracy: 0.7425
# Epoch 105/700
# 1/1 - 0s - loss: 0.6564 - binary_accuracy: 0.7271 - val_loss: 0.5675 - val_binary_accuracy: 0.7434
# Epoch 106/700
# 1/1 - 0s - loss: 0.6762 - binary_accuracy: 0.7096 - val_loss: 0.5556 - val_binary_accuracy: 0.7443
# Epoch 107/700
# 1/1 - 0s - loss: 0.5907 - binary_accuracy: 0.7339 - val_loss: 0.5529 - val_binary_accuracy: 0.7425
# Epoch 108/700
# 1/1 - 0s - loss: 0.6010 - binary_accuracy: 0.7524 - val_loss: 0.5509 - val_binary_accuracy: 0.7425
# Epoch 109/700
# 1/1 - 0s - loss: 0.6606 - binary_accuracy: 0.7300 - val_loss: 0.5409 - val_binary_accuracy: 0.7452
# Epoch 110/700
# 1/1 - 0s - loss: 0.6850 - binary_accuracy: 0.7417 - val_loss: 0.5819 - val_binary_accuracy: 0.7091
# Epoch 111/700
# 1/1 - 0s - loss: 0.6893 - binary_accuracy: 0.7125 - val_loss: 0.6366 - val_binary_accuracy: 0.6757
# Epoch 112/700
# 1/1 - 0s - loss: 0.6930 - binary_accuracy: 0.6667 - val_loss: 0.6267 - val_binary_accuracy: 0.6722
# Epoch 113/700
# 1/1 - 0s - loss: 0.7438 - binary_accuracy: 0.6832 - val_loss: 0.6121 - val_binary_accuracy: 0.6960
# Epoch 114/700
# 1/1 - 0s - loss: 0.6751 - binary_accuracy: 0.7057 - val_loss: 0.5924 - val_binary_accuracy: 0.7267
# Epoch 115/700
# 1/1 - 0s - loss: 0.5850 - binary_accuracy: 0.7320 - val_loss: 0.6292 - val_binary_accuracy: 0.7399
# Epoch 116/700
# 1/1 - 0s - loss: 0.7950 - binary_accuracy: 0.7203 - val_loss: 0.6812 - val_binary_accuracy: 0.7390
# Epoch 117/700
# 1/1 - 0s - loss: 0.8106 - binary_accuracy: 0.7437 - val_loss: 0.7475 - val_binary_accuracy: 0.7417
# Epoch 118/700
# 1/1 - 0s - loss: 0.8886 - binary_accuracy: 0.7066 - val_loss: 0.7980 - val_binary_accuracy: 0.7320
# Epoch 119/700
# 1/1 - 0s - loss: 0.8926 - binary_accuracy: 0.7281 - val_loss: 0.8831 - val_binary_accuracy: 0.7258
# Epoch 120/700
# 1/1 - 0s - loss: 1.0250 - binary_accuracy: 0.6988 - val_loss: 0.9135 - val_binary_accuracy: 0.7188
# Epoch 121/700
# 1/1 - 0s - loss: 1.0118 - binary_accuracy: 0.7164 - val_loss: 0.9183 - val_binary_accuracy: 0.7135
# Epoch 122/700
# 1/1 - 0s - loss: 1.1307 - binary_accuracy: 0.7115 - val_loss: 0.8507 - val_binary_accuracy: 0.7293
# Epoch 123/700
# 1/1 - 0s - loss: 0.9080 - binary_accuracy: 0.7154 - val_loss: 0.8003 - val_binary_accuracy: 0.7346
# Epoch 124/700
# 1/1 - 0s - loss: 0.8769 - binary_accuracy: 0.7222 - val_loss: 0.7508 - val_binary_accuracy: 0.7381
# Epoch 125/700
# 1/1 - 0s - loss: 0.7946 - binary_accuracy: 0.7057 - val_loss: 0.7099 - val_binary_accuracy: 0.7364
# Epoch 126/700
# 1/1 - 0s - loss: 0.7604 - binary_accuracy: 0.7057 - val_loss: 0.7049 - val_binary_accuracy: 0.7425
# Epoch 127/700
# 1/1 - 0s - loss: 0.7721 - binary_accuracy: 0.7378 - val_loss: 0.6947 - val_binary_accuracy: 0.7469
# Epoch 128/700
# 1/1 - 0s - loss: 0.6823 - binary_accuracy: 0.7417 - val_loss: 0.6787 - val_binary_accuracy: 0.7504
# Epoch 129/700
# 1/1 - 0s - loss: 0.7083 - binary_accuracy: 0.7144 - val_loss: 0.6653 - val_binary_accuracy: 0.7496
# Epoch 130/700
# 1/1 - 0s - loss: 0.6941 - binary_accuracy: 0.7427 - val_loss: 0.6224 - val_binary_accuracy: 0.7513
# Epoch 131/700
# 1/1 - 0s - loss: 0.6651 - binary_accuracy: 0.7251 - val_loss: 0.6165 - val_binary_accuracy: 0.7504
# Epoch 132/700
# 1/1 - 0s - loss: 0.7208 - binary_accuracy: 0.7339 - val_loss: 0.6141 - val_binary_accuracy: 0.7496
# Epoch 133/700
# 1/1 - 0s - loss: 0.6952 - binary_accuracy: 0.7242 - val_loss: 0.5942 - val_binary_accuracy: 0.7452
# Epoch 134/700
# 1/1 - 0s - loss: 0.6666 - binary_accuracy: 0.7222 - val_loss: 0.5791 - val_binary_accuracy: 0.7390
# Epoch 135/700
# 1/1 - 0s - loss: 0.7050 - binary_accuracy: 0.7251 - val_loss: 0.5693 - val_binary_accuracy: 0.7390
# Epoch 136/700
# 1/1 - 0s - loss: 0.6739 - binary_accuracy: 0.7242 - val_loss: 0.5695 - val_binary_accuracy: 0.7337
# Epoch 137/700
# 1/1 - 0s - loss: 0.6901 - binary_accuracy: 0.7339 - val_loss: 0.5702 - val_binary_accuracy: 0.7302
# Epoch 138/700
# 1/1 - 0s - loss: 0.6796 - binary_accuracy: 0.7271 - val_loss: 0.5706 - val_binary_accuracy: 0.7285
# Epoch 139/700
# 1/1 - 0s - loss: 0.6138 - binary_accuracy: 0.7144 - val_loss: 0.5706 - val_binary_accuracy: 0.7241
# Epoch 140/700
# 1/1 - 0s - loss: 0.6877 - binary_accuracy: 0.7105 - val_loss: 0.5701 - val_binary_accuracy: 0.7232
# Epoch 141/700
# 1/1 - 0s - loss: 0.6458 - binary_accuracy: 0.6998 - val_loss: 0.5682 - val_binary_accuracy: 0.7258
# Epoch 142/700
# 1/1 - 0s - loss: 0.6990 - binary_accuracy: 0.7086 - val_loss: 0.5645 - val_binary_accuracy: 0.7311
# Epoch 143/700
# 1/1 - 0s - loss: 0.6562 - binary_accuracy: 0.7320 - val_loss: 0.5693 - val_binary_accuracy: 0.7425
# Epoch 144/700
# 1/1 - 0s - loss: 0.5965 - binary_accuracy: 0.7573 - val_loss: 0.5642 - val_binary_accuracy: 0.7460
# Epoch 145/700
# 1/1 - 0s - loss: 0.6209 - binary_accuracy: 0.7339 - val_loss: 0.5513 - val_binary_accuracy: 0.7557
# Epoch 146/700
# 1/1 - 0s - loss: 0.7077 - binary_accuracy: 0.7427 - val_loss: 0.5486 - val_binary_accuracy: 0.7548
# Epoch 147/700
# 1/1 - 0s - loss: 0.5875 - binary_accuracy: 0.7290 - val_loss: 0.5548 - val_binary_accuracy: 0.7636
# Epoch 148/700
# 1/1 - 0s - loss: 0.6458 - binary_accuracy: 0.7602 - val_loss: 0.5628 - val_binary_accuracy: 0.7680
# Epoch 149/700
# 1/1 - 0s - loss: 0.6535 - binary_accuracy: 0.7349 - val_loss: 0.5628 - val_binary_accuracy: 0.7698
# Epoch 150/700
# 1/1 - 0s - loss: 0.6199 - binary_accuracy: 0.7437 - val_loss: 0.5625 - val_binary_accuracy: 0.7724
# Epoch 151/700
# 1/1 - 0s - loss: 0.6646 - binary_accuracy: 0.7417 - val_loss: 0.5605 - val_binary_accuracy: 0.7724
# Epoch 152/700
# 1/1 - 0s - loss: 0.6102 - binary_accuracy: 0.7398 - val_loss: 0.5589 - val_binary_accuracy: 0.7777
# Epoch 153/700
# 1/1 - 0s - loss: 0.5999 - binary_accuracy: 0.7359 - val_loss: 0.5578 - val_binary_accuracy: 0.7759
# Epoch 154/700
# 1/1 - 0s - loss: 0.6621 - binary_accuracy: 0.7368 - val_loss: 0.5570 - val_binary_accuracy: 0.7750
# Epoch 155/700
# 1/1 - 0s - loss: 0.6283 - binary_accuracy: 0.7456 - val_loss: 0.5562 - val_binary_accuracy: 0.7777
# Epoch 156/700
# 1/1 - 0s - loss: 0.6937 - binary_accuracy: 0.7466 - val_loss: 0.5351 - val_binary_accuracy: 0.7812
# Epoch 157/700
# 1/1 - 0s - loss: 0.6181 - binary_accuracy: 0.7388 - val_loss: 0.5273 - val_binary_accuracy: 0.7724
# Epoch 158/700
# 1/1 - 0s - loss: 0.5919 - binary_accuracy: 0.7563 - val_loss: 0.5304 - val_binary_accuracy: 0.7733
# Epoch 159/700
# 1/1 - 0s - loss: 0.6480 - binary_accuracy: 0.7505 - val_loss: 0.5615 - val_binary_accuracy: 0.7566
# Epoch 160/700
# 1/1 - 0s - loss: 0.5655 - binary_accuracy: 0.7329 - val_loss: 0.5673 - val_binary_accuracy: 0.7496
# Epoch 161/700
# 1/1 - 0s - loss: 0.5652 - binary_accuracy: 0.7329 - val_loss: 0.5622 - val_binary_accuracy: 0.7434
# Epoch 162/700
# 1/1 - 0s - loss: 0.5923 - binary_accuracy: 0.7505 - val_loss: 0.5477 - val_binary_accuracy: 0.7408
# Epoch 163/700
# 1/1 - 0s - loss: 0.6319 - binary_accuracy: 0.7641 - val_loss: 0.5464 - val_binary_accuracy: 0.7452
# Epoch 164/700
# 1/1 - 0s - loss: 0.5399 - binary_accuracy: 0.7378 - val_loss: 0.5501 - val_binary_accuracy: 0.7443
# Epoch 165/700
# 1/1 - 0s - loss: 0.6442 - binary_accuracy: 0.7242 - val_loss: 0.5564 - val_binary_accuracy: 0.7478
# Epoch 166/700
# 1/1 - 0s - loss: 0.5685 - binary_accuracy: 0.7368 - val_loss: 0.5546 - val_binary_accuracy: 0.7513
# Epoch 167/700
# 1/1 - 0s - loss: 0.6111 - binary_accuracy: 0.7310 - val_loss: 0.5423 - val_binary_accuracy: 0.7557
# Epoch 168/700
# 1/1 - 0s - loss: 0.6426 - binary_accuracy: 0.7271 - val_loss: 0.5369 - val_binary_accuracy: 0.7636
# Epoch 169/700
# 1/1 - 0s - loss: 0.5878 - binary_accuracy: 0.7437 - val_loss: 0.5330 - val_binary_accuracy: 0.7663
# Epoch 170/700
# 1/1 - 0s - loss: 0.5693 - binary_accuracy: 0.7602 - val_loss: 0.5416 - val_binary_accuracy: 0.7715
# Epoch 171/700
# 1/1 - 0s - loss: 0.5332 - binary_accuracy: 0.7680 - val_loss: 0.5466 - val_binary_accuracy: 0.7742
# Epoch 172/700
# 1/1 - 0s - loss: 0.5770 - binary_accuracy: 0.7602 - val_loss: 0.5550 - val_binary_accuracy: 0.7742
# Epoch 173/700
# 1/1 - 0s - loss: 0.5475 - binary_accuracy: 0.7544 - val_loss: 0.5648 - val_binary_accuracy: 0.7750
# Epoch 174/700
# 1/1 - 0s - loss: 0.6142 - binary_accuracy: 0.7573 - val_loss: 0.5652 - val_binary_accuracy: 0.7838
# Epoch 175/700
# 1/1 - 0s - loss: 0.6792 - binary_accuracy: 0.7495 - val_loss: 0.5657 - val_binary_accuracy: 0.7847
# Epoch 176/700
# 1/1 - 0s - loss: 0.5687 - binary_accuracy: 0.7719 - val_loss: 0.5573 - val_binary_accuracy: 0.7821
# Epoch 177/700
# 1/1 - 0s - loss: 0.6138 - binary_accuracy: 0.7680 - val_loss: 0.5558 - val_binary_accuracy: 0.7830
# Epoch 178/700
# 1/1 - 0s - loss: 0.5881 - binary_accuracy: 0.7466 - val_loss: 0.5544 - val_binary_accuracy: 0.7821
# Epoch 179/700
# 1/1 - 0s - loss: 0.6422 - binary_accuracy: 0.7515 - val_loss: 0.5532 - val_binary_accuracy: 0.7803
# Epoch 180/700
# 1/1 - 0s - loss: 0.6163 - binary_accuracy: 0.7544 - val_loss: 0.5597 - val_binary_accuracy: 0.7803
# Epoch 181/700
# 1/1 - 0s - loss: 0.5993 - binary_accuracy: 0.7505 - val_loss: 0.5480 - val_binary_accuracy: 0.7777
# Epoch 182/700
# 1/1 - 0s - loss: 0.6243 - binary_accuracy: 0.7836 - val_loss: 0.5458 - val_binary_accuracy: 0.7821
# Epoch 183/700
# 1/1 - 0s - loss: 0.5273 - binary_accuracy: 0.7768 - val_loss: 0.5352 - val_binary_accuracy: 0.7830
# Epoch 184/700
# 1/1 - 0s - loss: 0.5792 - binary_accuracy: 0.7583 - val_loss: 0.5346 - val_binary_accuracy: 0.7856
# Epoch 185/700
# 1/1 - 0s - loss: 0.5404 - binary_accuracy: 0.7602 - val_loss: 0.5255 - val_binary_accuracy: 0.7838
# Epoch 186/700
# 1/1 - 0s - loss: 0.5668 - binary_accuracy: 0.7505 - val_loss: 0.5253 - val_binary_accuracy: 0.7847
# Epoch 187/700
# 1/1 - 0s - loss: 0.5350 - binary_accuracy: 0.7622 - val_loss: 0.5163 - val_binary_accuracy: 0.7812
# Epoch 188/700
# 1/1 - 0s - loss: 0.6039 - binary_accuracy: 0.7739 - val_loss: 0.5175 - val_binary_accuracy: 0.7777
# Epoch 189/700
# 1/1 - 0s - loss: 0.6252 - binary_accuracy: 0.7729 - val_loss: 0.5311 - val_binary_accuracy: 0.7724
# Epoch 190/700
# 1/1 - 0s - loss: 0.6056 - binary_accuracy: 0.7622 - val_loss: 0.5352 - val_binary_accuracy: 0.7671
# Epoch 191/700
# 1/1 - 0s - loss: 0.5717 - binary_accuracy: 0.7485 - val_loss: 0.5384 - val_binary_accuracy: 0.7654
# Epoch 192/700
# 1/1 - 0s - loss: 0.5511 - binary_accuracy: 0.7632 - val_loss: 0.5407 - val_binary_accuracy: 0.7645
# Epoch 193/700
# 1/1 - 0s - loss: 0.5520 - binary_accuracy: 0.7437 - val_loss: 0.5424 - val_binary_accuracy: 0.7645
# Epoch 194/700
# 1/1 - 0s - loss: 0.5682 - binary_accuracy: 0.7807 - val_loss: 0.5526 - val_binary_accuracy: 0.7671
# Epoch 195/700
# 1/1 - 0s - loss: 0.5656 - binary_accuracy: 0.7632 - val_loss: 0.5606 - val_binary_accuracy: 0.7654
# Epoch 196/700
# 1/1 - 0s - loss: 0.5566 - binary_accuracy: 0.7505 - val_loss: 0.5573 - val_binary_accuracy: 0.7759
# Epoch 197/700
# 1/1 - 0s - loss: 0.5099 - binary_accuracy: 0.7554 - val_loss: 0.5670 - val_binary_accuracy: 0.7750
# Epoch 198/700
# 1/1 - 0s - loss: 0.5577 - binary_accuracy: 0.7875 - val_loss: 0.5853 - val_binary_accuracy: 0.7707
# Epoch 199/700
# 1/1 - 0s - loss: 0.5725 - binary_accuracy: 0.7719 - val_loss: 0.5767 - val_binary_accuracy: 0.7689
# Epoch 200/700
# 1/1 - 0s - loss: 0.5643 - binary_accuracy: 0.7641 - val_loss: 0.5757 - val_binary_accuracy: 0.7724
# Epoch 201/700
# 1/1 - 0s - loss: 0.5402 - binary_accuracy: 0.7622 - val_loss: 0.5693 - val_binary_accuracy: 0.7786
# Epoch 202/700
# 1/1 - 0s - loss: 0.5648 - binary_accuracy: 0.7641 - val_loss: 0.5793 - val_binary_accuracy: 0.7794
# Epoch 203/700
# 1/1 - 0s - loss: 0.5783 - binary_accuracy: 0.7554 - val_loss: 0.5950 - val_binary_accuracy: 0.7812
# Epoch 204/700
# 1/1 - 0s - loss: 0.6185 - binary_accuracy: 0.7524 - val_loss: 0.6278 - val_binary_accuracy: 0.7733
# Epoch 205/700
# 1/1 - 0s - loss: 0.6593 - binary_accuracy: 0.7505 - val_loss: 0.6622 - val_binary_accuracy: 0.7619
# Epoch 206/700
# 1/1 - 0s - loss: 0.6581 - binary_accuracy: 0.7466 - val_loss: 0.7053 - val_binary_accuracy: 0.7443
# Epoch 207/700
# 1/1 - 0s - loss: 0.8350 - binary_accuracy: 0.7495 - val_loss: 0.7884 - val_binary_accuracy: 0.7311
# Epoch 208/700
# 1/1 - 0s - loss: 0.9187 - binary_accuracy: 0.7105 - val_loss: 0.7957 - val_binary_accuracy: 0.7223
# Epoch 209/700
# 1/1 - 0s - loss: 1.0030 - binary_accuracy: 0.7339 - val_loss: 0.7810 - val_binary_accuracy: 0.7250
# Epoch 210/700
# 1/1 - 0s - loss: 0.8215 - binary_accuracy: 0.7339 - val_loss: 0.7391 - val_binary_accuracy: 0.7452
# Epoch 211/700
# 1/1 - 0s - loss: 0.8718 - binary_accuracy: 0.7378 - val_loss: 0.6511 - val_binary_accuracy: 0.7548
# Epoch 212/700
# 1/1 - 0s - loss: 0.7330 - binary_accuracy: 0.7310 - val_loss: 0.6222 - val_binary_accuracy: 0.7627
# Epoch 213/700
# 1/1 - 0s - loss: 0.6768 - binary_accuracy: 0.7359 - val_loss: 0.5892 - val_binary_accuracy: 0.7636
# Epoch 214/700
# 1/1 - 0s - loss: 0.6445 - binary_accuracy: 0.7505 - val_loss: 0.5427 - val_binary_accuracy: 0.7645
# Epoch 215/700
# 1/1 - 0s - loss: 0.5722 - binary_accuracy: 0.7602 - val_loss: 0.5247 - val_binary_accuracy: 0.7750
# Epoch 216/700
# 1/1 - 0s - loss: 0.5508 - binary_accuracy: 0.7583 - val_loss: 0.5304 - val_binary_accuracy: 0.7636
# Epoch 217/700
# 1/1 - 0s - loss: 0.6225 - binary_accuracy: 0.7437 - val_loss: 0.5359 - val_binary_accuracy: 0.7575
# Epoch 218/700
# 1/1 - 0s - loss: 0.5552 - binary_accuracy: 0.7544 - val_loss: 0.5316 - val_binary_accuracy: 0.7496
# Epoch 219/700
# 1/1 - 0s - loss: 0.5602 - binary_accuracy: 0.7427 - val_loss: 0.5352 - val_binary_accuracy: 0.7434
# Epoch 220/700
# 1/1 - 0s - loss: 0.5648 - binary_accuracy: 0.7398 - val_loss: 0.5361 - val_binary_accuracy: 0.7434
# Epoch 221/700
# 1/1 - 0s - loss: 0.5927 - binary_accuracy: 0.7320 - val_loss: 0.5356 - val_binary_accuracy: 0.7434
# Epoch 222/700
# 1/1 - 0s - loss: 0.6094 - binary_accuracy: 0.7290 - val_loss: 0.5231 - val_binary_accuracy: 0.7460
# Epoch 223/700
# 1/1 - 0s - loss: 0.6009 - binary_accuracy: 0.7290 - val_loss: 0.5171 - val_binary_accuracy: 0.7513
# Epoch 224/700
# 1/1 - 0s - loss: 0.5452 - binary_accuracy: 0.7329 - val_loss: 0.5116 - val_binary_accuracy: 0.7627
# Epoch 225/700
# 1/1 - 0s - loss: 0.5808 - binary_accuracy: 0.7602 - val_loss: 0.5076 - val_binary_accuracy: 0.7707
# Epoch 226/700
# 1/1 - 0s - loss: 0.5899 - binary_accuracy: 0.7446 - val_loss: 0.5063 - val_binary_accuracy: 0.7689
# Epoch 227/700
# 1/1 - 0s - loss: 0.5609 - binary_accuracy: 0.7505 - val_loss: 0.5259 - val_binary_accuracy: 0.7750
# Epoch 228/700
# 1/1 - 0s - loss: 0.6328 - binary_accuracy: 0.7300 - val_loss: 0.5358 - val_binary_accuracy: 0.7750
# Epoch 229/700
# 1/1 - 0s - loss: 0.5452 - binary_accuracy: 0.7505 - val_loss: 0.5546 - val_binary_accuracy: 0.7768
# Epoch 230/700
# 1/1 - 0s - loss: 0.5918 - binary_accuracy: 0.7554 - val_loss: 0.5562 - val_binary_accuracy: 0.7715
# Epoch 231/700
# 1/1 - 0s - loss: 0.5285 - binary_accuracy: 0.7407 - val_loss: 0.5580 - val_binary_accuracy: 0.7707
# Epoch 232/700
# 1/1 - 0s - loss: 0.6038 - binary_accuracy: 0.7495 - val_loss: 0.5586 - val_binary_accuracy: 0.7698
# Epoch 233/700
# 1/1 - 0s - loss: 0.6166 - binary_accuracy: 0.7641 - val_loss: 0.5585 - val_binary_accuracy: 0.7689
# Epoch 234/700
# 1/1 - 0s - loss: 0.6184 - binary_accuracy: 0.7563 - val_loss: 0.5559 - val_binary_accuracy: 0.7715
# Epoch 235/700
# 1/1 - 0s - loss: 0.5561 - binary_accuracy: 0.7680 - val_loss: 0.5528 - val_binary_accuracy: 0.7733
# Epoch 236/700
# 1/1 - 0s - loss: 0.6186 - binary_accuracy: 0.7700 - val_loss: 0.5502 - val_binary_accuracy: 0.7724
# Epoch 237/700
# 1/1 - 0s - loss: 0.5566 - binary_accuracy: 0.7583 - val_loss: 0.5291 - val_binary_accuracy: 0.7759
# Epoch 238/700
# 1/1 - 0s - loss: 0.6094 - binary_accuracy: 0.7505 - val_loss: 0.5064 - val_binary_accuracy: 0.7803
# Epoch 239/700
# 1/1 - 0s - loss: 0.5242 - binary_accuracy: 0.7583 - val_loss: 0.4940 - val_binary_accuracy: 0.7759
# Epoch 240/700
# 1/1 - 0s - loss: 0.5744 - binary_accuracy: 0.7544 - val_loss: 0.4941 - val_binary_accuracy: 0.7750
# Epoch 241/700
# 1/1 - 0s - loss: 0.5339 - binary_accuracy: 0.7632 - val_loss: 0.4952 - val_binary_accuracy: 0.7698
# Epoch 242/700
# 1/1 - 0s - loss: 0.4766 - binary_accuracy: 0.7641 - val_loss: 0.4963 - val_binary_accuracy: 0.7671
# Epoch 243/700
# 1/1 - 0s - loss: 0.5884 - binary_accuracy: 0.7641 - val_loss: 0.4975 - val_binary_accuracy: 0.7671
# Epoch 244/700
# 1/1 - 0s - loss: 0.5174 - binary_accuracy: 0.7632 - val_loss: 0.4981 - val_binary_accuracy: 0.7671
# Epoch 245/700
# 1/1 - 0s - loss: 0.5545 - binary_accuracy: 0.7612 - val_loss: 0.4978 - val_binary_accuracy: 0.7680
# Epoch 246/700
# 1/1 - 0s - loss: 0.5606 - binary_accuracy: 0.7476 - val_loss: 0.4965 - val_binary_accuracy: 0.7671
# Epoch 247/700
# 1/1 - 0s - loss: 0.5834 - binary_accuracy: 0.7622 - val_loss: 0.4950 - val_binary_accuracy: 0.7680
# Epoch 248/700
# 1/1 - 0s - loss: 0.5093 - binary_accuracy: 0.7719 - val_loss: 0.4915 - val_binary_accuracy: 0.7768
# Epoch 249/700
# 1/1 - 0s - loss: 0.5343 - binary_accuracy: 0.7807 - val_loss: 0.4898 - val_binary_accuracy: 0.7777
# Epoch 250/700
# 1/1 - 0s - loss: 0.5592 - binary_accuracy: 0.7622 - val_loss: 0.4890 - val_binary_accuracy: 0.7768
# Epoch 251/700
# 1/1 - 0s - loss: 0.5368 - binary_accuracy: 0.7739 - val_loss: 0.4986 - val_binary_accuracy: 0.7803
# Epoch 252/700
# 1/1 - 0s - loss: 0.5429 - binary_accuracy: 0.7817 - val_loss: 0.4998 - val_binary_accuracy: 0.7821
# Epoch 253/700
# 1/1 - 0s - loss: 0.5500 - binary_accuracy: 0.7778 - val_loss: 0.5041 - val_binary_accuracy: 0.7847
# Epoch 254/700
# 1/1 - 0s - loss: 0.4776 - binary_accuracy: 0.7505 - val_loss: 0.5173 - val_binary_accuracy: 0.7812
# Epoch 255/700
# 1/1 - 0s - loss: 0.5458 - binary_accuracy: 0.7612 - val_loss: 0.5442 - val_binary_accuracy: 0.7847
# Epoch 256/700
# 1/1 - 0s - loss: 0.5276 - binary_accuracy: 0.7768 - val_loss: 0.5449 - val_binary_accuracy: 0.7838
# Epoch 257/700
# 1/1 - 0s - loss: 0.5651 - binary_accuracy: 0.7943 - val_loss: 0.5450 - val_binary_accuracy: 0.7821
# Epoch 258/700
# 1/1 - 0s - loss: 0.4950 - binary_accuracy: 0.7749 - val_loss: 0.5449 - val_binary_accuracy: 0.7812
# Epoch 259/700
# 1/1 - 0s - loss: 0.5566 - binary_accuracy: 0.7534 - val_loss: 0.5433 - val_binary_accuracy: 0.7838
# Epoch 260/700
# 1/1 - 0s - loss: 0.5450 - binary_accuracy: 0.7749 - val_loss: 0.5335 - val_binary_accuracy: 0.7838
# Epoch 261/700
# 1/1 - 0s - loss: 0.5303 - binary_accuracy: 0.7690 - val_loss: 0.5098 - val_binary_accuracy: 0.7891
# Epoch 262/700
# 1/1 - 0s - loss: 0.5900 - binary_accuracy: 0.7651 - val_loss: 0.5081 - val_binary_accuracy: 0.7873
# Epoch 263/700
# 1/1 - 0s - loss: 0.5037 - binary_accuracy: 0.8012 - val_loss: 0.5109 - val_binary_accuracy: 0.7768
# Epoch 264/700
# 1/1 - 0s - loss: 0.5222 - binary_accuracy: 0.7846 - val_loss: 0.5369 - val_binary_accuracy: 0.7575
# Epoch 265/700
# 1/1 - 0s - loss: 0.6331 - binary_accuracy: 0.7505 - val_loss: 0.5410 - val_binary_accuracy: 0.7346
# Epoch 266/700
# 1/1 - 0s - loss: 0.5324 - binary_accuracy: 0.7437 - val_loss: 0.5466 - val_binary_accuracy: 0.7364
# Epoch 267/700
# 1/1 - 0s - loss: 0.6498 - binary_accuracy: 0.7456 - val_loss: 0.5556 - val_binary_accuracy: 0.7452
# Epoch 268/700
# 1/1 - 0s - loss: 0.5780 - binary_accuracy: 0.7671 - val_loss: 0.5623 - val_binary_accuracy: 0.7478
# Epoch 269/700
# 1/1 - 0s - loss: 0.5862 - binary_accuracy: 0.7573 - val_loss: 0.5595 - val_binary_accuracy: 0.7583
# Epoch 270/700
# 1/1 - 0s - loss: 0.6175 - binary_accuracy: 0.7583 - val_loss: 0.5652 - val_binary_accuracy: 0.7575
# Epoch 271/700
# 1/1 - 0s - loss: 0.5938 - binary_accuracy: 0.7602 - val_loss: 0.6437 - val_binary_accuracy: 0.7592
# Epoch 272/700
# 1/1 - 0s - loss: 0.6419 - binary_accuracy: 0.7534 - val_loss: 0.6814 - val_binary_accuracy: 0.7478
# Epoch 273/700
# 1/1 - 0s - loss: 0.7333 - binary_accuracy: 0.7437 - val_loss: 0.6894 - val_binary_accuracy: 0.7478
# Epoch 274/700
# 1/1 - 0s - loss: 0.6220 - binary_accuracy: 0.7398 - val_loss: 0.7052 - val_binary_accuracy: 0.7452
# Epoch 275/700
# 1/1 - 0s - loss: 0.6938 - binary_accuracy: 0.7544 - val_loss: 0.7159 - val_binary_accuracy: 0.7478
# Epoch 276/700
# 1/1 - 0s - loss: 0.6095 - binary_accuracy: 0.7671 - val_loss: 0.7004 - val_binary_accuracy: 0.7496
# Epoch 277/700
# 1/1 - 0s - loss: 0.6278 - binary_accuracy: 0.7622 - val_loss: 0.6846 - val_binary_accuracy: 0.7504
# Epoch 278/700
# 1/1 - 0s - loss: 0.7366 - binary_accuracy: 0.7388 - val_loss: 0.6557 - val_binary_accuracy: 0.7557
# Epoch 279/700
# 1/1 - 0s - loss: 0.6431 - binary_accuracy: 0.7349 - val_loss: 0.6124 - val_binary_accuracy: 0.7636
# Epoch 280/700
# 1/1 - 0s - loss: 0.6005 - binary_accuracy: 0.7534 - val_loss: 0.5660 - val_binary_accuracy: 0.7707
# Epoch 281/700
# 1/1 - 0s - loss: 0.6270 - binary_accuracy: 0.7583 - val_loss: 0.5632 - val_binary_accuracy: 0.7557
# Epoch 282/700
# 1/1 - 0s - loss: 0.6318 - binary_accuracy: 0.7632 - val_loss: 0.5646 - val_binary_accuracy: 0.7460
# Epoch 283/700
# 1/1 - 0s - loss: 0.6163 - binary_accuracy: 0.7378 - val_loss: 0.5566 - val_binary_accuracy: 0.7443
# Epoch 284/700
# 1/1 - 0s - loss: 0.6097 - binary_accuracy: 0.7437 - val_loss: 0.5557 - val_binary_accuracy: 0.7478
# Epoch 285/700
# 1/1 - 0s - loss: 0.6105 - binary_accuracy: 0.7329 - val_loss: 0.5464 - val_binary_accuracy: 0.7487
# Epoch 286/700
# 1/1 - 0s - loss: 0.6010 - binary_accuracy: 0.7573 - val_loss: 0.5425 - val_binary_accuracy: 0.7531
# Epoch 287/700
# 1/1 - 0s - loss: 0.5402 - binary_accuracy: 0.7719 - val_loss: 0.5391 - val_binary_accuracy: 0.7557
# Epoch 288/700
# 1/1 - 0s - loss: 0.5990 - binary_accuracy: 0.7398 - val_loss: 0.5446 - val_binary_accuracy: 0.7601
# Epoch 289/700
# 1/1 - 0s - loss: 0.5288 - binary_accuracy: 0.7632 - val_loss: 0.5407 - val_binary_accuracy: 0.7759
# Epoch 290/700
# 1/1 - 0s - loss: 0.6321 - binary_accuracy: 0.7505 - val_loss: 0.5366 - val_binary_accuracy: 0.7821
# Epoch 291/700
# 1/1 - 0s - loss: 0.5663 - binary_accuracy: 0.7788 - val_loss: 0.5342 - val_binary_accuracy: 0.7803
# Epoch 292/700
# 1/1 - 0s - loss: 0.6171 - binary_accuracy: 0.7544 - val_loss: 0.5429 - val_binary_accuracy: 0.7821
# Epoch 293/700
# 1/1 - 0s - loss: 0.5165 - binary_accuracy: 0.7651 - val_loss: 0.5572 - val_binary_accuracy: 0.7750
# Epoch 294/700
# 1/1 - 0s - loss: 0.5463 - binary_accuracy: 0.7739 - val_loss: 0.5724 - val_binary_accuracy: 0.7742
# Epoch 295/700
# 1/1 - 0s - loss: 0.5713 - binary_accuracy: 0.7729 - val_loss: 0.5740 - val_binary_accuracy: 0.7707
# Epoch 296/700
# 1/1 - 0s - loss: 0.6544 - binary_accuracy: 0.7495 - val_loss: 0.5737 - val_binary_accuracy: 0.7707
# Epoch 297/700
# 1/1 - 0s - loss: 0.5387 - binary_accuracy: 0.7661 - val_loss: 0.5715 - val_binary_accuracy: 0.7733
# Epoch 298/700
# 1/1 - 0s - loss: 0.5887 - binary_accuracy: 0.7602 - val_loss: 0.5688 - val_binary_accuracy: 0.7794
# Epoch 299/700
# 1/1 - 0s - loss: 0.6041 - binary_accuracy: 0.7661 - val_loss: 0.5576 - val_binary_accuracy: 0.7803
# Epoch 300/700
# 1/1 - 0s - loss: 0.5688 - binary_accuracy: 0.7739 - val_loss: 0.5359 - val_binary_accuracy: 0.7794
# Epoch 301/700
# 1/1 - 0s - loss: 0.5397 - binary_accuracy: 0.7602 - val_loss: 0.5355 - val_binary_accuracy: 0.7838
# Epoch 302/700
# 1/1 - 0s - loss: 0.5523 - binary_accuracy: 0.7632 - val_loss: 0.5373 - val_binary_accuracy: 0.7803
# Epoch 303/700
# 1/1 - 0s - loss: 0.5542 - binary_accuracy: 0.7602 - val_loss: 0.5312 - val_binary_accuracy: 0.7803
# Epoch 304/700
# 1/1 - 0s - loss: 0.5424 - binary_accuracy: 0.7515 - val_loss: 0.5414 - val_binary_accuracy: 0.7812
# Epoch 305/700
# 1/1 - 0s - loss: 0.5638 - binary_accuracy: 0.7671 - val_loss: 0.5493 - val_binary_accuracy: 0.7812
# Epoch 306/700
# 1/1 - 0s - loss: 0.5106 - binary_accuracy: 0.7680 - val_loss: 0.5571 - val_binary_accuracy: 0.7803
# Epoch 307/700
# 1/1 - 0s - loss: 0.5459 - binary_accuracy: 0.7700 - val_loss: 0.5557 - val_binary_accuracy: 0.7803
# Epoch 308/700
# 1/1 - 0s - loss: 0.6025 - binary_accuracy: 0.7807 - val_loss: 0.5465 - val_binary_accuracy: 0.7803
# Epoch 309/700
# 1/1 - 0s - loss: 0.5046 - binary_accuracy: 0.7768 - val_loss: 0.5475 - val_binary_accuracy: 0.7803
# Epoch 310/700
# 1/1 - 0s - loss: 0.5970 - binary_accuracy: 0.7690 - val_loss: 0.5557 - val_binary_accuracy: 0.7821
# Epoch 311/700
# 1/1 - 0s - loss: 0.5630 - binary_accuracy: 0.7612 - val_loss: 0.5561 - val_binary_accuracy: 0.7812
# Epoch 312/700
# 1/1 - 0s - loss: 0.5602 - binary_accuracy: 0.7632 - val_loss: 0.5658 - val_binary_accuracy: 0.7812
# Epoch 313/700
# 1/1 - 0s - loss: 0.5786 - binary_accuracy: 0.7700 - val_loss: 0.5581 - val_binary_accuracy: 0.7830
# Epoch 314/700
# 1/1 - 0s - loss: 0.5457 - binary_accuracy: 0.7778 - val_loss: 0.5590 - val_binary_accuracy: 0.7830
# Epoch 315/700
# 1/1 - 0s - loss: 0.5076 - binary_accuracy: 0.7680 - val_loss: 0.5601 - val_binary_accuracy: 0.7812
# Epoch 316/700
# 1/1 - 0s - loss: 0.5323 - binary_accuracy: 0.7680 - val_loss: 0.5608 - val_binary_accuracy: 0.7803
# Epoch 317/700
# 1/1 - 0s - loss: 0.5244 - binary_accuracy: 0.7768 - val_loss: 0.5612 - val_binary_accuracy: 0.7768
# Epoch 318/700
# 1/1 - 0s - loss: 0.4851 - binary_accuracy: 0.7758 - val_loss: 0.5614 - val_binary_accuracy: 0.7759
# Epoch 319/700
# 1/1 - 0s - loss: 0.5701 - binary_accuracy: 0.7622 - val_loss: 0.5625 - val_binary_accuracy: 0.7768
# Epoch 320/700
# 1/1 - 0s - loss: 0.5206 - binary_accuracy: 0.7729 - val_loss: 0.5630 - val_binary_accuracy: 0.7759
# Epoch 321/700
# 1/1 - 0s - loss: 0.5519 - binary_accuracy: 0.7680 - val_loss: 0.5636 - val_binary_accuracy: 0.7724
# Epoch 322/700
# 1/1 - 0s - loss: 0.5191 - binary_accuracy: 0.7778 - val_loss: 0.5548 - val_binary_accuracy: 0.7707
# Epoch 323/700
# 1/1 - 0s - loss: 0.5198 - binary_accuracy: 0.7573 - val_loss: 0.5538 - val_binary_accuracy: 0.7698
# Epoch 324/700
# 1/1 - 0s - loss: 0.5876 - binary_accuracy: 0.7719 - val_loss: 0.5528 - val_binary_accuracy: 0.7707
# Epoch 325/700
# 1/1 - 0s - loss: 0.5193 - binary_accuracy: 0.7710 - val_loss: 0.5514 - val_binary_accuracy: 0.7707
# Epoch 326/700
# 1/1 - 0s - loss: 0.6477 - binary_accuracy: 0.7690 - val_loss: 0.5497 - val_binary_accuracy: 0.7768
# Epoch 327/700
# 1/1 - 0s - loss: 0.5019 - binary_accuracy: 0.7778 - val_loss: 0.5487 - val_binary_accuracy: 0.7794
# Epoch 328/700
# 1/1 - 0s - loss: 0.5184 - binary_accuracy: 0.7904 - val_loss: 0.5566 - val_binary_accuracy: 0.7803
# Epoch 329/700
# 1/1 - 0s - loss: 0.5610 - binary_accuracy: 0.7739 - val_loss: 0.5635 - val_binary_accuracy: 0.7794
# Epoch 330/700
# 1/1 - 0s - loss: 0.5358 - binary_accuracy: 0.7827 - val_loss: 0.5623 - val_binary_accuracy: 0.7794
# Epoch 331/700
# 1/1 - 0s - loss: 0.5559 - binary_accuracy: 0.7739 - val_loss: 0.5618 - val_binary_accuracy: 0.7821
# Epoch 332/700
# 1/1 - 0s - loss: 0.4985 - binary_accuracy: 0.7924 - val_loss: 0.5627 - val_binary_accuracy: 0.7830
# Epoch 333/700
# 1/1 - 0s - loss: 0.5657 - binary_accuracy: 0.7700 - val_loss: 0.5646 - val_binary_accuracy: 0.7873
# Epoch 334/700
# 1/1 - 0s - loss: 0.5757 - binary_accuracy: 0.7554 - val_loss: 0.5634 - val_binary_accuracy: 0.7865
# Epoch 335/700
# 1/1 - 0s - loss: 0.5375 - binary_accuracy: 0.7827 - val_loss: 0.5621 - val_binary_accuracy: 0.7865
# Epoch 336/700
# 1/1 - 0s - loss: 0.4703 - binary_accuracy: 0.7827 - val_loss: 0.5513 - val_binary_accuracy: 0.7847
# Epoch 337/700
# 1/1 - 0s - loss: 0.5244 - binary_accuracy: 0.7885 - val_loss: 0.5313 - val_binary_accuracy: 0.7768
# Epoch 338/700
# 1/1 - 0s - loss: 0.5509 - binary_accuracy: 0.7778 - val_loss: 0.5122 - val_binary_accuracy: 0.7636
# Epoch 339/700
# 1/1 - 0s - loss: 0.5855 - binary_accuracy: 0.7641 - val_loss: 0.5032 - val_binary_accuracy: 0.7601
# Epoch 340/700
# 1/1 - 0s - loss: 0.5494 - binary_accuracy: 0.7602 - val_loss: 0.5778 - val_binary_accuracy: 0.7557
# Epoch 341/700
# 1/1 - 0s - loss: 0.6088 - binary_accuracy: 0.7427 - val_loss: 0.6719 - val_binary_accuracy: 0.7373
# Epoch 342/700
# 1/1 - 0s - loss: 0.6876 - binary_accuracy: 0.7466 - val_loss: 0.7946 - val_binary_accuracy: 0.7241
# Epoch 343/700
# 1/1 - 0s - loss: 0.7750 - binary_accuracy: 0.7183 - val_loss: 0.9331 - val_binary_accuracy: 0.7109
# Epoch 344/700
# 1/1 - 0s - loss: 0.8275 - binary_accuracy: 0.7271 - val_loss: 1.0517 - val_binary_accuracy: 0.6995
# Epoch 345/700
# 1/1 - 0s - loss: 0.9374 - binary_accuracy: 0.7183 - val_loss: 1.0654 - val_binary_accuracy: 0.6977
# Epoch 346/700
# 1/1 - 0s - loss: 1.0672 - binary_accuracy: 0.6871 - val_loss: 0.9806 - val_binary_accuracy: 0.7039
# Epoch 347/700
# 1/1 - 0s - loss: 0.9411 - binary_accuracy: 0.7076 - val_loss: 0.6824 - val_binary_accuracy: 0.7364
# Epoch 348/700
# 1/1 - 0s - loss: 0.6827 - binary_accuracy: 0.7378 - val_loss: 0.5963 - val_binary_accuracy: 0.7399
# Epoch 349/700
# 1/1 - 0s - loss: 0.6018 - binary_accuracy: 0.7417 - val_loss: 0.5999 - val_binary_accuracy: 0.7197
# Epoch 350/700
# 1/1 - 0s - loss: 0.6355 - binary_accuracy: 0.7144 - val_loss: 0.6297 - val_binary_accuracy: 0.7021
# Epoch 351/700
# 1/1 - 0s - loss: 0.6686 - binary_accuracy: 0.7086 - val_loss: 0.6186 - val_binary_accuracy: 0.7004
# Epoch 352/700
# 1/1 - 0s - loss: 0.6747 - binary_accuracy: 0.7018 - val_loss: 0.6402 - val_binary_accuracy: 0.7004
# Epoch 353/700
# 1/1 - 0s - loss: 0.6927 - binary_accuracy: 0.6862 - val_loss: 0.6287 - val_binary_accuracy: 0.7197
# Epoch 354/700
# 1/1 - 0s - loss: 0.6233 - binary_accuracy: 0.7096 - val_loss: 0.6329 - val_binary_accuracy: 0.7258
# Epoch 355/700
# 1/1 - 0s - loss: 0.7691 - binary_accuracy: 0.7066 - val_loss: 0.6533 - val_binary_accuracy: 0.7232
# Epoch 356/700
# 1/1 - 0s - loss: 0.6902 - binary_accuracy: 0.7086 - val_loss: 0.6589 - val_binary_accuracy: 0.7267
# Epoch 357/700
# 1/1 - 0s - loss: 0.7854 - binary_accuracy: 0.7242 - val_loss: 0.6645 - val_binary_accuracy: 0.7285
# Epoch 358/700
# 1/1 - 0s - loss: 0.7474 - binary_accuracy: 0.7125 - val_loss: 0.6668 - val_binary_accuracy: 0.7311
# Epoch 359/700
# 1/1 - 0s - loss: 0.8574 - binary_accuracy: 0.6988 - val_loss: 0.6624 - val_binary_accuracy: 0.7320
# Epoch 360/700
# 1/1 - 0s - loss: 0.7243 - binary_accuracy: 0.7222 - val_loss: 0.6535 - val_binary_accuracy: 0.7320
# Epoch 361/700
# 1/1 - 0s - loss: 0.6426 - binary_accuracy: 0.7066 - val_loss: 0.6464 - val_binary_accuracy: 0.7373
# Epoch 362/700
# 1/1 - 0s - loss: 0.7195 - binary_accuracy: 0.7329 - val_loss: 0.6616 - val_binary_accuracy: 0.6810
# Epoch 363/700
# 1/1 - 0s - loss: 0.7377 - binary_accuracy: 0.6881 - val_loss: 0.7052 - val_binary_accuracy: 0.6388
# Epoch 364/700
# 1/1 - 0s - loss: 0.7769 - binary_accuracy: 0.6598 - val_loss: 0.7297 - val_binary_accuracy: 0.6643
# Epoch 365/700
# 1/1 - 0s - loss: 0.7760 - binary_accuracy: 0.6725 - val_loss: 0.7543 - val_binary_accuracy: 0.6951
# Epoch 366/700
# 1/1 - 0s - loss: 0.6381 - binary_accuracy: 0.7261 - val_loss: 0.9389 - val_binary_accuracy: 0.7083
# Epoch 367/700
# 1/1 - 0s - loss: 0.8200 - binary_accuracy: 0.7212 - val_loss: 1.4478 - val_binary_accuracy: 0.6626
# Epoch 368/700
# 1/1 - 0s - loss: 1.2949 - binary_accuracy: 0.6793 - val_loss: 2.0761 - val_binary_accuracy: 0.6063
# Epoch 369/700
# 1/1 - 0s - loss: 1.8913 - binary_accuracy: 0.6589 - val_loss: 2.6661 - val_binary_accuracy: 0.5756
# Epoch 370/700
# 1/1 - 0s - loss: 2.3635 - binary_accuracy: 0.6218 - val_loss: 3.0131 - val_binary_accuracy: 0.5580
# Epoch 371/700
# 1/1 - 0s - loss: 2.7832 - binary_accuracy: 0.6101 - val_loss: 3.0270 - val_binary_accuracy: 0.5589
# Epoch 372/700
# 1/1 - 0s - loss: 2.7856 - binary_accuracy: 0.5975 - val_loss: 2.5427 - val_binary_accuracy: 0.5747
# Epoch 373/700
# 1/1 - 0s - loss: 2.3487 - binary_accuracy: 0.6209 - val_loss: 1.2980 - val_binary_accuracy: 0.6714
# Epoch 374/700
# 1/1 - 0s - loss: 1.1803 - binary_accuracy: 0.6862 - val_loss: 0.6247 - val_binary_accuracy: 0.7250
# Epoch 375/700
# 1/1 - 0s - loss: 0.5832 - binary_accuracy: 0.7232 - val_loss: 0.5843 - val_binary_accuracy: 0.7206
# Epoch 376/700
# 1/1 - 0s - loss: 0.6115 - binary_accuracy: 0.7261 - val_loss: 0.5707 - val_binary_accuracy: 0.7346
# Epoch 377/700
# 1/1 - 0s - loss: 0.6430 - binary_accuracy: 0.7427 - val_loss: 0.6431 - val_binary_accuracy: 0.7522
# Epoch 378/700
# 1/1 - 0s - loss: 0.6631 - binary_accuracy: 0.7320 - val_loss: 0.9103 - val_binary_accuracy: 0.7118
# Epoch 379/700
# 1/1 - 0s - loss: 0.8190 - binary_accuracy: 0.7310 - val_loss: 1.5703 - val_binary_accuracy: 0.6564
# Epoch 380/700
# 1/1 - 0s - loss: 1.4216 - binary_accuracy: 0.6676 - val_loss: 2.0871 - val_binary_accuracy: 0.6116
# Epoch 381/700
# 1/1 - 0s - loss: 1.9050 - binary_accuracy: 0.6530 - val_loss: 2.6209 - val_binary_accuracy: 0.5931
# Epoch 382/700
# 1/1 - 0s - loss: 2.7980 - binary_accuracy: 0.6160 - val_loss: 1.2141 - val_binary_accuracy: 0.6705
# Epoch 383/700
# 1/1 - 0s - loss: 1.4249 - binary_accuracy: 0.6881 - val_loss: 0.7593 - val_binary_accuracy: 0.7258
# Epoch 384/700
# 1/1 - 0s - loss: 0.7495 - binary_accuracy: 0.7339 - val_loss: 0.7037 - val_binary_accuracy: 0.7276
# Epoch 385/700
# 1/1 - 0s - loss: 0.6881 - binary_accuracy: 0.7183 - val_loss: 0.7978 - val_binary_accuracy: 0.7091
# Epoch 386/700
# 1/1 - 0s - loss: 0.8469 - binary_accuracy: 0.7144 - val_loss: 1.1519 - val_binary_accuracy: 0.6845
# Epoch 387/700
# 1/1 - 0s - loss: 1.3424 - binary_accuracy: 0.6745 - val_loss: 1.7381 - val_binary_accuracy: 0.6415
# Epoch 388/700
# 1/1 - 0s - loss: 1.9277 - binary_accuracy: 0.6355 - val_loss: 2.4159 - val_binary_accuracy: 0.5993
# Epoch 389/700
# 1/1 - 0s - loss: 2.4405 - binary_accuracy: 0.6092 - val_loss: 2.9903 - val_binary_accuracy: 0.5773
# Epoch 390/700
# 1/1 - 0s - loss: 2.8079 - binary_accuracy: 0.6014 - val_loss: 3.2233 - val_binary_accuracy: 0.5641
# Epoch 391/700
# 1/1 - 0s - loss: 3.0882 - binary_accuracy: 0.6043 - val_loss: 3.4134 - val_binary_accuracy: 0.5562
# Epoch 392/700
# 1/1 - 0s - loss: 3.0601 - binary_accuracy: 0.5936 - val_loss: 3.4339 - val_binary_accuracy: 0.5554
# Epoch 393/700
# 1/1 - 0s - loss: 3.4435 - binary_accuracy: 0.5780 - val_loss: 3.3345 - val_binary_accuracy: 0.5536
# Epoch 394/700
# 1/1 - 0s - loss: 2.9965 - binary_accuracy: 0.5916 - val_loss: 2.9593 - val_binary_accuracy: 0.5685
# Epoch 395/700
# 1/1 - 0s - loss: 2.8954 - binary_accuracy: 0.5916 - val_loss: 2.1817 - val_binary_accuracy: 0.5967
# Epoch 396/700
# 1/1 - 0s - loss: 2.1893 - binary_accuracy: 0.6355 - val_loss: 1.5676 - val_binary_accuracy: 0.6467
# Epoch 397/700
# 1/1 - 0s - loss: 1.5964 - binary_accuracy: 0.6569 - val_loss: 1.0595 - val_binary_accuracy: 0.6801
# Epoch 398/700
# 1/1 - 0s - loss: 1.0110 - binary_accuracy: 0.6667 - val_loss: 0.7867 - val_binary_accuracy: 0.7144
# Epoch 399/700
# 1/1 - 0s - loss: 0.8066 - binary_accuracy: 0.7144 - val_loss: 0.7115 - val_binary_accuracy: 0.7487
# Epoch 400/700
# 1/1 - 0s - loss: 0.6696 - binary_accuracy: 0.7378 - val_loss: 0.6791 - val_binary_accuracy: 0.7575
# Epoch 401/700
# 1/1 - 0s - loss: 0.6592 - binary_accuracy: 0.7524 - val_loss: 0.6679 - val_binary_accuracy: 0.7566
# Epoch 402/700
# 1/1 - 0s - loss: 0.6640 - binary_accuracy: 0.7135 - val_loss: 0.6726 - val_binary_accuracy: 0.7425
# Epoch 403/700
# 1/1 - 0s - loss: 0.6788 - binary_accuracy: 0.7339 - val_loss: 0.6794 - val_binary_accuracy: 0.7443
# Epoch 404/700
# 1/1 - 0s - loss: 0.6939 - binary_accuracy: 0.7066 - val_loss: 0.6946 - val_binary_accuracy: 0.7434
# Epoch 405/700
# 1/1 - 0s - loss: 0.6905 - binary_accuracy: 0.7349 - val_loss: 0.6966 - val_binary_accuracy: 0.7417
# Epoch 406/700
# 1/1 - 0s - loss: 0.7773 - binary_accuracy: 0.7281 - val_loss: 0.7090 - val_binary_accuracy: 0.7390
# Epoch 407/700
# 1/1 - 0s - loss: 0.6208 - binary_accuracy: 0.7193 - val_loss: 0.7113 - val_binary_accuracy: 0.7364
# Epoch 408/700
# 1/1 - 0s - loss: 0.7263 - binary_accuracy: 0.7183 - val_loss: 0.7134 - val_binary_accuracy: 0.7346
# Epoch 409/700
# 1/1 - 0s - loss: 0.6824 - binary_accuracy: 0.7125 - val_loss: 0.7233 - val_binary_accuracy: 0.7346
# Epoch 410/700
# 1/1 - 0s - loss: 0.7567 - binary_accuracy: 0.7242 - val_loss: 0.7237 - val_binary_accuracy: 0.7320
# Epoch 411/700
# 1/1 - 0s - loss: 0.6428 - binary_accuracy: 0.7271 - val_loss: 0.7155 - val_binary_accuracy: 0.7337
# Epoch 412/700
# 1/1 - 0s - loss: 0.6955 - binary_accuracy: 0.7115 - val_loss: 0.7137 - val_binary_accuracy: 0.7346
# Epoch 413/700
# 1/1 - 0s - loss: 0.6842 - binary_accuracy: 0.7378 - val_loss: 0.7034 - val_binary_accuracy: 0.7364
# Epoch 414/700
# 1/1 - 0s - loss: 0.6799 - binary_accuracy: 0.7300 - val_loss: 0.7007 - val_binary_accuracy: 0.7381
# Epoch 415/700
# 1/1 - 0s - loss: 0.6925 - binary_accuracy: 0.7398 - val_loss: 0.6986 - val_binary_accuracy: 0.7408
# Epoch 416/700
# 1/1 - 0s - loss: 0.6340 - binary_accuracy: 0.7300 - val_loss: 0.6780 - val_binary_accuracy: 0.7364
# Epoch 417/700
# 1/1 - 0s - loss: 0.6353 - binary_accuracy: 0.7154 - val_loss: 0.6503 - val_binary_accuracy: 0.7381
# Epoch 418/700
# 1/1 - 0s - loss: 0.5921 - binary_accuracy: 0.7349 - val_loss: 0.6529 - val_binary_accuracy: 0.7425
# Epoch 419/700
# 1/1 - 0s - loss: 0.5920 - binary_accuracy: 0.7524 - val_loss: 0.6347 - val_binary_accuracy: 0.7487
# Epoch 420/700
# 1/1 - 0s - loss: 0.6330 - binary_accuracy: 0.7261 - val_loss: 0.6081 - val_binary_accuracy: 0.7540
# Epoch 421/700
# 1/1 - 0s - loss: 0.5832 - binary_accuracy: 0.7310 - val_loss: 0.5938 - val_binary_accuracy: 0.7540
# Epoch 422/700
# ...
# Epoch 443/700
# 1/1 - 0s - loss: 0.5672 - binary_accuracy: 0.7524 - val_loss: 0.5690 - val_binary_accuracy: 0.7504
# Epoch 444/700
# 1/1 - 0s - loss: 0.4756 - binary_accuracy: 0.7749 - val_loss: 0.5406 - val_binary_accuracy: 0.7504
# Epoch 445/700
# 1/1 - 0s - loss: 0.5507 - binary_accuracy: 0.7417 - val_loss: 0.5370 - val_binary_accuracy: 0.7496
# Epoch 446/700
# 1/1 - 0s - loss: 0.5058 - binary_accuracy: 0.7407 - val_loss: 0.5345 - val_binary_accuracy: 0.7531
# Epoch 447/700
# 1/1 - 0s - loss: 0.5144 - binary_accuracy: 0.7622 - val_loss: 0.5320 - val_binary_accuracy: 0.7540
# Epoch 448/700
# 1/1 - 0s - loss: 0.5098 - binary_accuracy: 0.7554 - val_loss: 0.5297 - val_binary_accuracy: 0.7566
# Epoch 449/700
# 1/1 - 0s - loss: 0.5189 - binary_accuracy: 0.7641 - val_loss: 0.5274 - val_binary_accuracy: 0.7592
# Epoch 450/700
# 1/1 - 0s - loss: 0.5326 - binary_accuracy: 0.7563 - val_loss: 0.5250 - val_binary_accuracy: 0.7654
# Epoch 451/700
# 1/1 - 0s - loss: 0.5246 - binary_accuracy: 0.7602 - val_loss: 0.5227 - val_binary_accuracy: 0.7689
# Epoch 452/700
# 1/1 - 0s - loss: 0.5201 - binary_accuracy: 0.7778 - val_loss: 0.5204 - val_binary_accuracy: 0.7698
# Epoch 453/700
# 1/1 - 0s - loss: 0.5484 - binary_accuracy: 0.7534 - val_loss: 0.5186 - val_binary_accuracy: 0.7794
# Epoch 454/700
# 1/1 - 0s - loss: 0.5215 - binary_accuracy: 0.7446 - val_loss: 0.5188 - val_binary_accuracy: 0.7838
# Epoch 455/700
# 1/1 - 0s - loss: 0.5204 - binary_accuracy: 0.7593 - val_loss: 0.5253 - val_binary_accuracy: 0.7856
# Epoch 456/700
# 1/1 - 0s - loss: 0.5124 - binary_accuracy: 0.7632 - val_loss: 0.5244 - val_binary_accuracy: 0.7882
# Epoch 457/700
# 1/1 - 0s - loss: 0.5657 - binary_accuracy: 0.7593 - val_loss: 0.5155 - val_binary_accuracy: 0.7953
# Epoch 458/700
# 1/1 - 0s - loss: 0.4985 - binary_accuracy: 0.7758 - val_loss: 0.5139 - val_binary_accuracy: 0.7944
# Epoch 459/700
# 1/1 - 0s - loss: 0.5372 - binary_accuracy: 0.7661 - val_loss: 0.5133 - val_binary_accuracy: 0.7935
# Epoch 460/700
# 1/1 - 0s - loss: 0.5835 - binary_accuracy: 0.7583 - val_loss: 0.5131 - val_binary_accuracy: 0.7953
# Epoch 461/700
# 1/1 - 0s - loss: 0.5306 - binary_accuracy: 0.7749 - val_loss: 0.5268 - val_binary_accuracy: 0.7373
# Epoch 462/700
# 1/1 - 0s - loss: 0.5215 - binary_accuracy: 0.7534 - val_loss: 0.5598 - val_binary_accuracy: 0.7232
# Epoch 463/700
# 1/1 - 0s - loss: 0.5937 - binary_accuracy: 0.7193 - val_loss: 0.5563 - val_binary_accuracy: 0.7188
# Epoch 464/700
# 1/1 - 0s - loss: 0.6258 - binary_accuracy: 0.7339 - val_loss: 0.5643 - val_binary_accuracy: 0.7285
# Epoch 465/700
# 1/1 - 0s - loss: 0.6074 - binary_accuracy: 0.7476 - val_loss: 0.6188 - val_binary_accuracy: 0.7504
# Epoch 466/700
# 1/1 - 0s - loss: 0.7352 - binary_accuracy: 0.7368 - val_loss: 0.7314 - val_binary_accuracy: 0.7346
# Epoch 467/700
# 1/1 - 0s - loss: 0.7977 - binary_accuracy: 0.7320 - val_loss: 0.9645 - val_binary_accuracy: 0.7144
# Epoch 468/700
# 1/1 - 0s - loss: 0.9885 - binary_accuracy: 0.7027 - val_loss: 1.2120 - val_binary_accuracy: 0.6740
# Epoch 469/700
# 1/1 - 0s - loss: 1.0997 - binary_accuracy: 0.6823 - val_loss: 1.5320 - val_binary_accuracy: 0.6406
# Epoch 470/700
# 1/1 - 0s - loss: 1.0921 - binary_accuracy: 0.6725 - val_loss: 1.8821 - val_binary_accuracy: 0.6186
# Epoch 471/700
# 1/1 - 0s - loss: 1.6955 - binary_accuracy: 0.6511 - val_loss: 2.0114 - val_binary_accuracy: 0.6037
# Epoch 472/700
# 1/1 - 0s - loss: 1.8481 - binary_accuracy: 0.6218 - val_loss: 2.0608 - val_binary_accuracy: 0.6002
# Epoch 473/700
# 1/1 - 0s - loss: 1.9746 - binary_accuracy: 0.6267 - val_loss: 2.0701 - val_binary_accuracy: 0.6011
# Epoch 474/700
# 1/1 - 0s - loss: 2.0605 - binary_accuracy: 0.6179 - val_loss: 1.9459 - val_binary_accuracy: 0.6072
# Epoch 475/700
# 1/1 - 0s - loss: 1.6447 - binary_accuracy: 0.6345 - val_loss: 1.7042 - val_binary_accuracy: 0.6213
# Epoch 476/700
# 1/1 - 0s - loss: 1.6139 - binary_accuracy: 0.6355 - val_loss: 1.4516 - val_binary_accuracy: 0.6432
# Epoch 477/700
# 1/1 - 0s - loss: 1.3770 - binary_accuracy: 0.6589 - val_loss: 1.2262 - val_binary_accuracy: 0.6670
# Epoch 478/700
# 1/1 - 0s - loss: 1.1356 - binary_accuracy: 0.6618 - val_loss: 0.9895 - val_binary_accuracy: 0.6942
# Epoch 479/700
# 1/1 - 0s - loss: 0.9150 - binary_accuracy: 0.7018 - val_loss: 0.7907 - val_binary_accuracy: 0.7197
# Epoch 480/700
# 1/1 - 0s - loss: 0.7255 - binary_accuracy: 0.7290 - val_loss: 0.6884 - val_binary_accuracy: 0.7381
# Epoch 481/700
# 1/1 - 0s - loss: 0.6565 - binary_accuracy: 0.7320 - val_loss: 0.6388 - val_binary_accuracy: 0.7487
# Epoch 482/700
# 1/1 - 0s - loss: 0.6114 - binary_accuracy: 0.7446 - val_loss: 0.6019 - val_binary_accuracy: 0.7267
# Epoch 483/700
# 1/1 - 0s - loss: 0.6338 - binary_accuracy: 0.7388 - val_loss: 0.6545 - val_binary_accuracy: 0.7127
# Epoch 484/700
# 1/1 - 0s - loss: 0.7002 - binary_accuracy: 0.7164 - val_loss: 0.8024 - val_binary_accuracy: 0.7083
# Epoch 485/700
# 1/1 - 0s - loss: 0.7812 - binary_accuracy: 0.7339 - val_loss: 1.2821 - val_binary_accuracy: 0.6968
# Epoch 486/700
# 1/1 - 0s - loss: 1.0191 - binary_accuracy: 0.6901 - val_loss: 1.8482 - val_binary_accuracy: 0.6274
# Epoch 487/700
# 1/1 - 0s - loss: 1.9517 - binary_accuracy: 0.6618 - val_loss: 2.8177 - val_binary_accuracy: 0.5694
# Epoch 488/700
# 1/1 - 0s - loss: 2.4870 - binary_accuracy: 0.6238 - val_loss: 3.1734 - val_binary_accuracy: 0.5527
# Epoch 489/700
# 1/1 - 0s - loss: 2.9163 - binary_accuracy: 0.5975 - val_loss: 3.6845 - val_binary_accuracy: 0.5457
# Epoch 490/700
# 1/1 - 0s - loss: 3.4783 - binary_accuracy: 0.5682 - val_loss: 4.0327 - val_binary_accuracy: 0.5422
# Epoch 491/700
# 1/1 - 0s - loss: 3.8660 - binary_accuracy: 0.5614 - val_loss: 4.2910 - val_binary_accuracy: 0.5334
# Epoch 492/700
# 1/1 - 0s - loss: 3.9970 - binary_accuracy: 0.5575 - val_loss: 4.3970 - val_binary_accuracy: 0.5308
# Epoch 493/700
# 1/1 - 0s - loss: 4.1476 - binary_accuracy: 0.5614 - val_loss: 4.1153 - val_binary_accuracy: 0.5378
# Epoch 494/700
# 1/1 - 0s - loss: 3.6188 - binary_accuracy: 0.5653 - val_loss: 3.6802 - val_binary_accuracy: 0.5439
# Epoch 495/700
# 1/1 - 0s - loss: 3.4692 - binary_accuracy: 0.5663 - val_loss: 3.1795 - val_binary_accuracy: 0.5510
# Epoch 496/700
# 1/1 - 0s - loss: 2.8297 - binary_accuracy: 0.5965 - val_loss: 2.8122 - val_binary_accuracy: 0.5650
# Epoch 497/700
# 1/1 - 0s - loss: 2.6305 - binary_accuracy: 0.5984 - val_loss: 2.3070 - val_binary_accuracy: 0.5782
# Epoch 498/700
# 1/1 - 0s - loss: 2.4991 - binary_accuracy: 0.6140 - val_loss: 1.8477 - val_binary_accuracy: 0.6134
# Epoch 499/700
# 1/1 - 0s - loss: 1.8674 - binary_accuracy: 0.6394 - val_loss: 1.4480 - val_binary_accuracy: 0.6353
# Epoch 500/700
# 1/1 - 0s - loss: 1.5195 - binary_accuracy: 0.6647 - val_loss: 1.1335 - val_binary_accuracy: 0.6722
# Epoch 501/700
# 1/1 - 0s - loss: 1.2741 - binary_accuracy: 0.6774 - val_loss: 0.8850 - val_binary_accuracy: 0.7127
# Epoch 502/700
# 1/1 - 0s - loss: 0.7456 - binary_accuracy: 0.7456 - val_loss: 0.7346 - val_binary_accuracy: 0.7496
# Epoch 503/700
# 1/1 - 0s - loss: 0.7919 - binary_accuracy: 0.7183 - val_loss: 0.6282 - val_binary_accuracy: 0.7707
# Epoch 504/700
# 1/1 - 0s - loss: 0.5327 - binary_accuracy: 0.7641 - val_loss: 0.5883 - val_binary_accuracy: 0.7838
# Epoch 505/700
# 1/1 - 0s - loss: 0.6178 - binary_accuracy: 0.7778 - val_loss: 0.5634 - val_binary_accuracy: 0.7865
# Epoch 506/700
# 1/1 - 0s - loss: 0.4974 - binary_accuracy: 0.7797 - val_loss: 0.5658 - val_binary_accuracy: 0.7777
# Epoch 507/700
# 1/1 - 0s - loss: 0.5203 - binary_accuracy: 0.7641 - val_loss: 0.5710 - val_binary_accuracy: 0.7707
# Epoch 508/700
# 1/1 - 0s - loss: 0.5245 - binary_accuracy: 0.7690 - val_loss: 0.5762 - val_binary_accuracy: 0.7645
# Epoch 509/700
# 1/1 - 0s - loss: 0.5499 - binary_accuracy: 0.7875 - val_loss: 0.5810 - val_binary_accuracy: 0.7575
# Epoch 510/700
# 1/1 - 0s - loss: 0.5972 - binary_accuracy: 0.7593 - val_loss: 0.5858 - val_binary_accuracy: 0.7540
# Epoch 511/700
# 1/1 - 0s - loss: 0.5415 - binary_accuracy: 0.7661 - val_loss: 0.5975 - val_binary_accuracy: 0.7504
# Epoch 512/700
# 1/1 - 0s - loss: 0.6187 - binary_accuracy: 0.7495 - val_loss: 0.6000 - val_binary_accuracy: 0.7504
# Epoch 513/700
# 1/1 - 0s - loss: 0.5858 - binary_accuracy: 0.7524 - val_loss: 0.6018 - val_binary_accuracy: 0.7469
# Epoch 514/700
# 1/1 - 0s - loss: 0.5923 - binary_accuracy: 0.7505 - val_loss: 0.6038 - val_binary_accuracy: 0.7496
# Epoch 515/700
# 1/1 - 0s - loss: 0.6177 - binary_accuracy: 0.7602 - val_loss: 0.6115 - val_binary_accuracy: 0.7531
# Epoch 516/700
# 1/1 - 0s - loss: 0.6424 - binary_accuracy: 0.7466 - val_loss: 0.6037 - val_binary_accuracy: 0.7575
# Epoch 517/700
# 1/1 - 0s - loss: 0.5896 - binary_accuracy: 0.7583 - val_loss: 0.6014 - val_binary_accuracy: 0.7610
# Epoch 518/700
# 1/1 - 0s - loss: 0.6095 - binary_accuracy: 0.7349 - val_loss: 0.5906 - val_binary_accuracy: 0.7619
# Epoch 519/700
# 1/1 - 0s - loss: 0.6910 - binary_accuracy: 0.7388 - val_loss: 0.5887 - val_binary_accuracy: 0.7654
# Epoch 520/700
# 1/1 - 0s - loss: 0.7104 - binary_accuracy: 0.7173 - val_loss: 0.5873 - val_binary_accuracy: 0.7689
# Epoch 521/700
# 1/1 - 0s - loss: 0.6399 - binary_accuracy: 0.7437 - val_loss: 0.5860 - val_binary_accuracy: 0.7680
# Epoch 522/700
# 1/1 - 0s - loss: 0.6351 - binary_accuracy: 0.7544 - val_loss: 0.5852 - val_binary_accuracy: 0.7671
# Epoch 523/700
# 1/1 - 0s - loss: 0.6229 - binary_accuracy: 0.7446 - val_loss: 0.5854 - val_binary_accuracy: 0.7663
# Epoch 524/700
# 1/1 - 0s - loss: 0.6151 - binary_accuracy: 0.7758 - val_loss: 0.5838 - val_binary_accuracy: 0.7671
# Epoch 525/700
# 1/1 - 0s - loss: 0.6582 - binary_accuracy: 0.7368 - val_loss: 0.5894 - val_binary_accuracy: 0.7680
# Epoch 526/700
# 1/1 - 0s - loss: 0.5764 - binary_accuracy: 0.7632 - val_loss: 0.5770 - val_binary_accuracy: 0.7707
# Epoch 527/700
# 1/1 - 0s - loss: 0.6121 - binary_accuracy: 0.7388 - val_loss: 0.5647 - val_binary_accuracy: 0.7707
# Epoch 528/700
# 1/1 - 0s - loss: 0.5581 - binary_accuracy: 0.7602 - val_loss: 0.5619 - val_binary_accuracy: 0.7750
# Epoch 529/700
# 1/1 - 0s - loss: 0.5522 - binary_accuracy: 0.7690 - val_loss: 0.5598 - val_binary_accuracy: 0.7742
# Epoch 530/700
# 1/1 - 0s - loss: 0.5625 - binary_accuracy: 0.7661 - val_loss: 0.5486 - val_binary_accuracy: 0.7715
# Epoch 531/700
# 1/1 - 0s - loss: 0.5958 - binary_accuracy: 0.7700 - val_loss: 0.5381 - val_binary_accuracy: 0.7742
# Epoch 532/700
# 1/1 - 0s - loss: 0.5487 - binary_accuracy: 0.7524 - val_loss: 0.5343 - val_binary_accuracy: 0.7750
# Epoch 533/700
# 1/1 - 0s - loss: 0.5672 - binary_accuracy: 0.7690 - val_loss: 0.5322 - val_binary_accuracy: 0.7733
# Epoch 534/700
# 1/1 - 0s - loss: 0.5420 - binary_accuracy: 0.7719 - val_loss: 0.5304 - val_binary_accuracy: 0.7803
# Epoch 535/700
# 1/1 - 0s - loss: 0.5295 - binary_accuracy: 0.7749 - val_loss: 0.5287 - val_binary_accuracy: 0.7838
# Epoch 536/700
# 1/1 - 0s - loss: 0.5712 - binary_accuracy: 0.7593 - val_loss: 0.5272 - val_binary_accuracy: 0.7856
# Epoch 537/700
# 1/1 - 0s - loss: 0.5329 - binary_accuracy: 0.7632 - val_loss: 0.5257 - val_binary_accuracy: 0.7891
# Epoch 538/700
# 1/1 - 0s - loss: 0.5283 - binary_accuracy: 0.7719 - val_loss: 0.5243 - val_binary_accuracy: 0.7882
# Epoch 539/700
# 1/1 - 0s - loss: 0.5244 - binary_accuracy: 0.7671 - val_loss: 0.5231 - val_binary_accuracy: 0.7891
# Epoch 540/700
# 1/1 - 0s - loss: 0.5449 - binary_accuracy: 0.7544 - val_loss: 0.5220 - val_binary_accuracy: 0.7882
# Epoch 541/700
# 1/1 - 0s - loss: 0.5145 - binary_accuracy: 0.7827 - val_loss: 0.5211 - val_binary_accuracy: 0.7891
# Epoch 542/700
# 1/1 - 0s - loss: 0.5186 - binary_accuracy: 0.7739 - val_loss: 0.5207 - val_binary_accuracy: 0.7909
# Epoch 543/700
# 1/1 - 0s - loss: 0.4949 - binary_accuracy: 0.7680 - val_loss: 0.5289 - val_binary_accuracy: 0.7926
# Epoch 544/700
# 1/1 - 0s - loss: 0.5238 - binary_accuracy: 0.7719 - val_loss: 0.5280 - val_binary_accuracy: 0.7953
# Epoch 545/700
# 1/1 - 0s - loss: 0.4889 - binary_accuracy: 0.7456 - val_loss: 0.5184 - val_binary_accuracy: 0.7926
# Epoch 546/700
# 1/1 - 0s - loss: 0.5781 - binary_accuracy: 0.7534 - val_loss: 0.5171 - val_binary_accuracy: 0.7926
# Epoch 547/700
# 1/1 - 0s - loss: 0.5766 - binary_accuracy: 0.7690 - val_loss: 0.5163 - val_binary_accuracy: 0.7961
# Epoch 548/700
# 1/1 - 0s - loss: 0.5454 - binary_accuracy: 0.7758 - val_loss: 0.5159 - val_binary_accuracy: 0.7953
# Epoch 549/700
# 1/1 - 0s - loss: 0.4978 - binary_accuracy: 0.7788 - val_loss: 0.5158 - val_binary_accuracy: 0.7953
# Epoch 550/700
# 1/1 - 0s - loss: 0.4978 - binary_accuracy: 0.7729 - val_loss: 0.5162 - val_binary_accuracy: 0.7979
# Epoch 551/700
# 1/1 - 0s - loss: 0.5462 - binary_accuracy: 0.7612 - val_loss: 0.5246 - val_binary_accuracy: 0.8005
# Epoch 552/700
# 1/1 - 0s - loss: 0.5224 - binary_accuracy: 0.7865 - val_loss: 0.5243 - val_binary_accuracy: 0.7996
# Epoch 553/700
# 1/1 - 0s - loss: 0.5113 - binary_accuracy: 0.7836 - val_loss: 0.5241 - val_binary_accuracy: 0.7988
# Epoch 554/700
# 1/1 - 0s - loss: 0.5211 - binary_accuracy: 0.7710 - val_loss: 0.5239 - val_binary_accuracy: 0.7996
# Epoch 555/700
# 1/1 - 0s - loss: 0.5834 - binary_accuracy: 0.7554 - val_loss: 0.5237 - val_binary_accuracy: 0.7988
# Epoch 556/700
# 1/1 - 0s - loss: 0.4944 - binary_accuracy: 0.7807 - val_loss: 0.5235 - val_binary_accuracy: 0.8005
# Epoch 557/700
# 1/1 - 0s - loss: 0.5277 - binary_accuracy: 0.7895 - val_loss: 0.5230 - val_binary_accuracy: 0.7996
# Epoch 558/700
# 1/1 - 0s - loss: 0.5432 - binary_accuracy: 0.7885 - val_loss: 0.5225 - val_binary_accuracy: 0.7988
# Epoch 559/700
# 1/1 - 0s - loss: 0.4971 - binary_accuracy: 0.7729 - val_loss: 0.5223 - val_binary_accuracy: 0.7979
# Epoch 560/700
# 1/1 - 0s - loss: 0.5241 - binary_accuracy: 0.7680 - val_loss: 0.5222 - val_binary_accuracy: 0.7979
# Epoch 561/700
# 1/1 - 0s - loss: 0.5280 - binary_accuracy: 0.7953 - val_loss: 0.5222 - val_binary_accuracy: 0.7970
# Epoch 562/700
# 1/1 - 0s - loss: 0.5172 - binary_accuracy: 0.7690 - val_loss: 0.5223 - val_binary_accuracy: 0.7996
# Epoch 563/700
# 1/1 - 0s - loss: 0.4596 - binary_accuracy: 0.7739 - val_loss: 0.5225 - val_binary_accuracy: 0.7979
# Epoch 564/700
# 1/1 - 0s - loss: 0.5454 - binary_accuracy: 0.7554 - val_loss: 0.5226 - val_binary_accuracy: 0.7970
# Epoch 565/700
# 1/1 - 0s - loss: 0.5116 - binary_accuracy: 0.7632 - val_loss: 0.5228 - val_binary_accuracy: 0.7979
# Epoch 566/700
# 1/1 - 0s - loss: 0.5607 - binary_accuracy: 0.7719 - val_loss: 0.5230 - val_binary_accuracy: 0.7979
# Epoch 567/700
# 1/1 - 0s - loss: 0.5084 - binary_accuracy: 0.7836 - val_loss: 0.5231 - val_binary_accuracy: 0.7996
# Epoch 568/700
# 1/1 - 0s - loss: 0.5362 - binary_accuracy: 0.7778 - val_loss: 0.5225 - val_binary_accuracy: 0.7970
# Epoch 569/700
# 1/1 - 0s - loss: 0.5243 - binary_accuracy: 0.7573 - val_loss: 0.5220 - val_binary_accuracy: 0.7988
# Epoch 570/700
# 1/1 - 0s - loss: 0.5346 - binary_accuracy: 0.7885 - val_loss: 0.5216 - val_binary_accuracy: 0.7961
# Epoch 571/700
# 1/1 - 0s - loss: 0.5317 - binary_accuracy: 0.7524 - val_loss: 0.5215 - val_binary_accuracy: 0.7961
# Epoch 572/700
# 1/1 - 0s - loss: 0.4919 - binary_accuracy: 0.7797 - val_loss: 0.5215 - val_binary_accuracy: 0.7970
# Epoch 573/700
# 1/1 - 0s - loss: 0.5147 - binary_accuracy: 0.7749 - val_loss: 0.5214 - val_binary_accuracy: 0.7961
# Epoch 574/700
# 1/1 - 0s - loss: 0.5152 - binary_accuracy: 0.7739 - val_loss: 0.5213 - val_binary_accuracy: 0.7979
# Epoch 575/700
# 1/1 - 0s - loss: 0.5193 - binary_accuracy: 0.7739 - val_loss: 0.5213 - val_binary_accuracy: 0.7979
# Epoch 576/700
# 1/1 - 0s - loss: 0.5283 - binary_accuracy: 0.7690 - val_loss: 0.5213 - val_binary_accuracy: 0.7970
# Epoch 577/700
# 1/1 - 0s - loss: 0.5419 - binary_accuracy: 0.7651 - val_loss: 0.5213 - val_binary_accuracy: 0.7996
# Epoch 578/700
# 1/1 - 0s - loss: 0.4864 - binary_accuracy: 0.7768 - val_loss: 0.5214 - val_binary_accuracy: 0.7988
# Epoch 579/700
# 1/1 - 0s - loss: 0.4814 - binary_accuracy: 0.7768 - val_loss: 0.5215 - val_binary_accuracy: 0.7988
# Epoch 580/700
# 1/1 - 0s - loss: 0.4511 - binary_accuracy: 0.7807 - val_loss: 0.5215 - val_binary_accuracy: 0.7979
# Epoch 581/700
# 1/1 - 0s - loss: 0.5450 - binary_accuracy: 0.7768 - val_loss: 0.5214 - val_binary_accuracy: 0.7970
# Epoch 582/700
# 1/1 - 0s - loss: 0.4546 - binary_accuracy: 0.7797 - val_loss: 0.5214 - val_binary_accuracy: 0.7970
# Epoch 583/700
# 1/1 - 0s - loss: 0.4859 - binary_accuracy: 0.7836 - val_loss: 0.5212 - val_binary_accuracy: 0.7970

# %%
sg.utils.plot_history(history)

# %%
train_metrics = model.evaluate(train_flow)
test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))

# %%
test_metrics

# %%
res_pred = model.predict(test_flow)

# %%
tmp = pd.DataFrame({"pred": res_pred[0], "label": edge_labels_test})
tmp

# %%
accuracy_score(edge_labels_test, res_pred[0]>0.4), roc_auc_score(edge_labels_test, res_pred[0])

# %%
import seaborn as sns, numpy as np
sns.distplot(tmp[tmp.label==1].pred)
sns.distplot(tmp[tmp.label==0].pred, color="r")
